# %%
from hyperopt import fmin, hp, tpe, Trials
import numpy as np

import os
import sys

BASEDIR = os.path.dirname(os.getcwd())
sys.path.append(BASEDIR)

from copy import deepcopy
from dgl.dataloading import GraphDataLoader
from src.model.attentivefp_postnet import attentivefpPostNet
from src.utils.mol.attfp_graph import MoleculeDataset, collate_fn
from src.config.attentivefp_postnet import attentivefpPostNetArgs
from src.pipeline.ensemble import training_ensemble_models
from src.utils.basic.logger import Writer
from src.utils.model.metrics import accuracy, roc_auc_score, prc_auc, F1, MCC, expected_calibration_error, OverconfidentFalseRate, OverconfidentFalseNegatives, Brier
import torch
import pandas as pd

# %% [markdown]
# # Initialize

# %%
torch.set_num_threads(4)

target_name = "pgp"
gpu_num     = 0

h_p = {'hidden_size': 600,
       'p_dropout'  : 0.05,
       'T'          : 2,
       'radius'     : 3,
       'ffn_num_layers': 3,
       'init_lr' : 0.002,
       'latent_dim': 6,
       'n_density': 2,
       'density_type': 'iaf_flow'
}

INT_KEYS = ['hidden_size', 'ffn_num_layers', 'n_density', 'latent_dim']

# %% [markdown]
# # Training function

# %%
SAVEDIR = os.path.join(BASEDIR, "results", target_name, 'AttFpPost')
DATADIR = os.path.join(BASEDIR, "data", target_name)
n = 0
logger = Writer(os.path.join(SAVEDIR, "history.log"))
def func(hyperparams):
    logger(" ")
    logger(" ")

    global n

    for key in INT_KEYS:
        hyperparams[key] = int(hyperparams[key])

    config = attentivefpPostNetArgs().parse_args([], known_only=True)
    hyper_args = deepcopy(config)
    save_dir = os.path.join(SAVEDIR)

    for key, value in hyperparams.items():
        setattr(hyper_args, key, value)

    setattr(hyper_args, "dataset_type", "classification")
    setattr(hyper_args, "latent_dim", int(hyper_args.latent_dim))
    setattr(hyper_args, 'metric', "roc-auc")
    setattr(hyper_args, "extra_metrics", ["MCC", "prc-auc", "accuracy", "F1"])
    setattr(hyper_args, "ffn_hidden_size", hyper_args.hidden_size)
    setattr(hyper_args, "early_stopping_num", 30)
    setattr(hyper_args, "gpu", gpu_num)
    setattr(hyper_args, "log_frequency", 20)
    setattr(hyper_args, "batch_size", 64)
    setattr(hyper_args, "at_least_epoch", 60)
    print(hyper_args)

    for i in range(10):

        train_dataset = MoleculeDataset(os.path.join(DATADIR, "tenfold", f"train_{i}.csv"))
        valid_dataset = MoleculeDataset(os.path.join(DATADIR, "tenfold", f"valid_{i}.csv"))
        test_dataset  = MoleculeDataset(os.path.join(DATADIR, "ind_152.csv"))

        train_dataloader = GraphDataLoader(dataset=train_dataset, collate_fn=collate_fn, batch_size=128, drop_last=False, shuffle=True)
        train_dataloader.smiles = [[s] for s in train_dataset.smiles_list]
        valid_dataloader = GraphDataLoader(dataset=valid_dataset, collate_fn=collate_fn, batch_size=128, drop_last=False, shuffle=False)
        valid_dataloader.smiles = [[s] for s in valid_dataset.smiles_list]
        test_dataloader  = GraphDataLoader(dataset=test_dataset,  collate_fn=collate_fn, batch_size=128, drop_last=False, shuffle=False)
        test_dataloader.smiles  = [[s] for s in test_dataset.smiles_list]
        
        train_targets = []
        for _, t in train_dataset:
            train_targets.append(t)

        N = torch.tensor([len(train_targets) - np.sum(train_targets).astype(np.int64),
                        np.sum(train_targets).astype(np.int64)], dtype=torch.float64)

        setattr(hyper_args, "N", N)
        
        training_ensemble_models(os.path.join(save_dir, f"fold_{i}"),
                                 attentivefpPostNet,
                                 hyper_args,
                                 train_dataloader,
                                 valid_dataloader=valid_dataloader,
                                 test_dataloader=test_dataloader,
                                 ensemble_num=1)
        
        test_prediction = []
        
        valid_ROC = []
        valid_PRC = []
        valid_ACC = []
        valid_MCC = []
        valid_F1  = []
        valid_ECE = []
        valid_OFR = []
        valid_OFN = []
        valid_Brier = []
        
        test_ROC  = []
        test_PRC  = []
        test_ACC  = []
        test_MCC  = []
        test_F1   = []
        test_ECE  = []
        test_OFR = []
        test_OFN = []
        test_Brier = []

    for i in range(10):
    
        temp_dir = os.path.join(save_dir, f"fold_{i}", "model_0")
        
        temp_valid_prediction = pd.read_csv(os.path.join(temp_dir, "valid_prediction.csv"))["property_pred"].to_numpy()
        temp_valid_label = pd.read_csv(os.path.join(temp_dir, "valid_prediction.csv"))["property_label"].to_numpy()
        
        temp_test_prediction = pd.read_csv(os.path.join(temp_dir, "test_prediction.csv"))["property_pred"].to_numpy()
        test_label = pd.read_csv(os.path.join(temp_dir, "test_prediction.csv"))["property_label"].to_numpy()
        test_prediction.append(temp_test_prediction) # for ensemble calculation
        
        valid_ROC.append(pd.read_csv(os.path.join(temp_dir, "valid_prediction_performance.csv"))["roc-auc"].iloc[0])
        valid_PRC.append(pd.read_csv(os.path.join(temp_dir, "valid_prediction_performance.csv"))["prc-auc"].iloc[0])
        valid_ACC.append(pd.read_csv(os.path.join(temp_dir, "valid_prediction_performance.csv"))["accuracy"].iloc[0])
        valid_MCC.append(pd.read_csv(os.path.join(temp_dir, "valid_prediction_performance.csv"))["MCC"].iloc[0])
        valid_F1.append(pd.read_csv(os.path.join(temp_dir, "valid_prediction_performance.csv"))["F1"].iloc[0])
        valid_ECE.append(expected_calibration_error(temp_valid_label, temp_valid_prediction, bins=10))
        valid_OFR.append(OverconfidentFalseRate(temp_valid_prediction, temp_valid_label))
        valid_OFN.append(OverconfidentFalseNegatives(temp_valid_prediction, temp_valid_label))
        valid_Brier.append(Brier(temp_valid_label,temp_valid_prediction))
        
        test_ROC.append(pd.read_csv(os.path.join(temp_dir, "test_prediction_performance.csv"))["roc-auc"].iloc[0])
        test_PRC.append(pd.read_csv(os.path.join(temp_dir, "test_prediction_performance.csv"))["prc-auc"].iloc[0])
        test_ACC.append(pd.read_csv(os.path.join(temp_dir, "test_prediction_performance.csv"))["accuracy"].iloc[0])
        test_MCC.append(pd.read_csv(os.path.join(temp_dir, "test_prediction_performance.csv"))["MCC"].iloc[0])
        test_F1.append(pd.read_csv(os.path.join(temp_dir, "test_prediction_performance.csv"))["F1"].iloc[0])
        test_ECE.append(expected_calibration_error(test_label, temp_test_prediction, bins=10))
        test_OFR.append(OverconfidentFalseRate(temp_test_prediction, test_label))
        test_OFN.append(OverconfidentFalseNegatives(temp_test_prediction, test_label))
        test_Brier.append(Brier(test_label,temp_test_prediction))
        

    logger(f'ROUND {n} Valid ROC-AUC {np.mean(valid_ROC)} +/- {np.std(valid_ROC)}')
    logger(f'ROUND {n} Valid PRC-AUC {np.mean(valid_PRC)} +/- {np.std(valid_PRC)}')
    logger(f'ROUND {n} Valid ACC     {np.mean(valid_ACC)} +/- {np.std(valid_ACC)}')
    logger(f'ROUND {n} Valid MCC     {np.mean(valid_MCC)} +/- {np.std(valid_MCC)}')
    logger(f'ROUND {n} Valid F1      {np.mean(valid_F1)} +/- {np.std(valid_F1)}')
    logger(f'ROUND {n} Valid ECE     {np.mean(valid_ECE)} +/- {np.std(valid_ECE)}')
    logger(f'ROUND {n} Valid OFR     {np.mean(valid_OFR)} +/- {np.std(valid_OFR)}')
    logger(f'ROUND {n} Valid OFN     {np.mean(valid_OFN)} +/- {np.std(valid_OFN)}')
    logger(f'ROUND {n} Valid Brier   {np.mean(valid_Brier)} +/- {np.std(valid_Brier)}')
    logger(' ')
    logger(f'ROUND {n} Test ROC-AUC {np.mean(test_ROC)} +/- {np.std(test_ROC)}')
    logger(f'ROUND {n} Test PRC-AUC {np.mean(test_PRC)} +/- {np.std(test_PRC)}')
    logger(f'ROUND {n} Test ACC     {np.mean(test_ACC)} +/- {np.std(test_ACC)}')
    logger(f'ROUND {n} Test MCC     {np.mean(test_MCC)} +/- {np.std(test_MCC)}')
    logger(f'ROUND {n} Test F1      {np.mean(test_F1)} +/- {np.std(test_F1)}')
    logger(f'ROUND {n} Test ECE     {np.mean(test_ECE)} +/- {np.std(test_ECE)}')
    logger(f'ROUND {n} Test OFR     {np.mean(test_OFR)} +/- {np.std(test_OFR)}')
    logger(f'ROUND {n} Test OFN     {np.mean(test_OFN)} +/- {np.std(test_OFN)}')
    logger(f'ROUND {n} Test Brier   {np.mean(test_Brier)} +/- {np.std(test_Brier)}')
    logger(' ')
    logger(f'ROUND {n} Ensemble Test ROC-AUC {roc_auc_score(test_label, np.mean(test_prediction, axis=0))}')
    logger(f'ROUND {n} Ensemble Test PRC-AUC {prc_auc(test_label, np.mean(test_prediction, axis=0))}')
    logger(f'ROUND {n} Ensemble Test ACC {accuracy(test_label, np.mean(test_prediction, axis=0))}')
    logger(f'ROUND {n} Ensemble Test MCC {MCC(test_label, np.mean(test_prediction, axis=0))}')
    logger(f'ROUND {n} Ensemble Test F1 {F1(test_label, np.mean(test_prediction, axis=0))}')
    logger(f'ROUND {n} Ensemble Test ECE {expected_calibration_error(test_label, np.mean(test_prediction, axis=0), bins=10)}')
    logger(f'ROUND {n} Ensemble Test OFR {OverconfidentFalseRate(np.mean(test_prediction, axis=0), test_label)}')
    logger(f'ROUND {n} Ensemble Test OFN {OverconfidentFalseNegatives(np.mean(test_prediction, axis=0), test_label)}')
    logger(f'ROUND {n} Ensemble Test Brier {Brier(test_label, np.mean(test_prediction, axis=0))}')
    logger(' ')

    return -np.mean(valid_ROC)

func(h_p)
# Out:
# 07-17 04:22:15
# 07-17 04:22:15
# {'N': [100, 100],
#  'T': 2,
#  'activation': 'ReLU',
#  'aggregation': 'mean',
#  'aggregation_norm': 100,
#  'at_least_epoch': 60,
#  'atom_descriptors': None,
#  'atom_descriptors_size': None,
#  'atom_messages': False,
#  'batch_size': 64,
#  'bias': False,
#  'cuda': True,
#  'dataset_type': 'classification',
#  'density_type': 'iaf_flow',
#  'depth': 3,
#  'device': device(type='cuda', index=0),
#  'dropout': 0.0,
#  'early_stopping_num': 30,
#  'empty_cache': False,
#  'explicit_h': False,
#  'extra_metrics': ['MCC', 'prc-auc', 'accuracy', 'F1'],
#  'features_only': False,
#  'features_size': None,
#  'ffn_hidden_size': 600,
#  'ffn_num_layers': 3,
#  'fingerprint_dim': 200,
#  'gpu': 0,
#  'grad_clip': None,
#  'hidden_size': 600,
#  'init_lr': 0.002,
#  'input_feature_dim': 200,
#  'latent_dim': 6,
#  'log_frequency': 20,
#  'loss_func': <function UCE_loss at 0x7f41bd940820>,
#  'metric': 'roc-auc',
#  'metrics': ['roc-auc', 'MCC', 'prc-auc', 'accuracy', 'F1'],
#  'minimize_score': False,
#  'mpn_shared': False,
#  'multiclass_num_classes': 3,
#  'n_density': 2,
#  'no_cache_mol': False,
#  'no_cuda': False,
#  'num_tasks': 1,
#  'number_of_molecules': 1,
#  'p_dropout': 0.05,
#  'pytorch_seed': 0,
#  'quiet': False,
#  'radius': 3,
#  'reaction': False,
#  'reaction_mode': 'reac_diff',
#  'task_names': ['property'],
#  'undirected': False,
#  'use_input_features': False}
# 1850it [00:04, 430.52it/s]
# 206it [00:00, 463.48it/s]
# 152it [00:00, 448.47it/s]
# 07-17 04:22:20	Training 0th model.
# 07-17 04:23:50
# 07-17 04:23:50	Start Evaluating on Evaluation Set, EPOCH 60 BATCH 900
# 100%|██████████| 2/2 [00:00<00:00, 18.96it/s]
# 07-17 04:23:50	roc-auc: 0.567
# 07-17 04:23:50	MCC: 0.446
# 07-17 04:23:50	prc-auc: 0.631
# 07-17 04:23:50	accuracy: 0.728
# 07-17 04:23:50	F1: 0.815
# 07-17 04:23:52
# 07-17 04:23:52	Start Evaluating on Evaluation Set, EPOCH 62 BATCH 920
# 100%|██████████| 2/2 [00:00<00:00, 19.19it/s]
# 07-17 04:23:53	roc-auc: 0.777
# 07-17 04:23:53	MCC: 0.488
# 07-17 04:23:53	prc-auc: 0.801
# 07-17 04:23:53	accuracy: 0.748
# 07-17 04:23:53	F1: 0.826
# 07-17 04:23:55
# 07-17 04:23:55	Start Evaluating on Evaluation Set, EPOCH 63 BATCH 940
# 100%|██████████| 2/2 [00:00<00:00, 19.52it/s]
# 07-17 04:23:55	roc-auc: 0.907
# 07-17 04:23:55	MCC: 0.655
# 07-17 04:23:55	prc-auc: 0.928
# 07-17 04:23:55	accuracy: 0.835
# 07-17 04:23:55	F1: 0.875
# 07-17 04:23:57
# 07-17 04:23:57	Start Evaluating on Evaluation Set, EPOCH 64 BATCH 960
# 100%|██████████| 2/2 [00:00<00:00, 20.32it/s]
# 07-17 04:23:57	roc-auc: 0.922
# 07-17 04:23:57	MCC: 0.687
# 07-17 04:23:57	prc-auc: 0.923
# 07-17 04:23:57	accuracy: 0.850
# 07-17 04:23:57	F1: 0.874
# 07-17 04:23:59
# 07-17 04:23:59	Start Evaluating on Evaluation Set, EPOCH 66 BATCH 980
# 100%|██████████| 2/2 [00:00<00:00, 19.52it/s]
# 07-17 04:23:59	roc-auc: 0.846
# 07-17 04:23:59	MCC: 0.424
# 07-17 04:23:59	prc-auc: 0.889
# 07-17 04:23:59	accuracy: 0.680
# 07-17 04:23:59	F1: 0.680
# 07-17 04:23:59	Model not improve for 1 Epochs.
# 07-17 04:23:59	Best roc-auc Now: 0.922
# 07-17 04:24:01
# 07-17 04:24:01	Start Evaluating on Evaluation Set, EPOCH 67 BATCH 1000
# 100%|██████████| 2/2 [00:00<00:00, 19.45it/s]
# 07-17 04:24:01	roc-auc: 0.686
# 07-17 04:24:01	MCC: 0.299
# 07-17 04:24:01	prc-auc: 0.756
# 07-17 04:24:01	accuracy: 0.612
# 07-17 04:24:01	F1: 0.600
# 07-17 04:24:01	Model not improve for 2 Epochs.
# 07-17 04:24:01	Best roc-auc Now: 0.922
# 07-17 04:24:03
# 07-17 04:24:03	Start Evaluating on Evaluation Set, EPOCH 68 BATCH 1020
# 100%|██████████| 2/2 [00:00<00:00, 19.21it/s]
# 07-17 04:24:04	roc-auc: 0.669
# 07-17 04:24:04	MCC: 0.062
# 07-17 04:24:04	prc-auc: 0.717
# 07-17 04:24:04	accuracy: 0.408
# 07-17 04:24:04	F1: 0.062
# 07-17 04:24:04	Model not improve for 3 Epochs.
# 07-17 04:24:04	Best roc-auc Now: 0.922
# 07-17 04:24:06
# 07-17 04:24:06	Start Evaluating on Evaluation Set, EPOCH 70 BATCH 1040
# 100%|██████████| 2/2 [00:00<00:00, 21.80it/s]
# 07-17 04:24:06	roc-auc: 0.871
# 07-17 04:24:06	MCC: 0.410
# 07-17 04:24:06	prc-auc: 0.866
# 07-17 04:24:06	accuracy: 0.665
# 07-17 04:24:06	F1: 0.657
# 07-17 04:24:06	Model not improve for 4 Epochs.
# 07-17 04:24:06	Best roc-auc Now: 0.922
# 07-17 04:24:08
# 07-17 04:24:08	Start Evaluating on Evaluation Set, EPOCH 71 BATCH 1060
# 100%|██████████| 2/2 [00:00<00:00, 20.40it/s]
# 07-17 04:24:08	roc-auc: 0.903
# 07-17 04:24:08	MCC: 0.620
# 07-17 04:24:08	prc-auc: 0.898
# 07-17 04:24:08	accuracy: 0.816
# 07-17 04:24:08	F1: 0.844
# 07-17 04:24:08	Model not improve for 5 Epochs.
# 07-17 04:24:08	Best roc-auc Now: 0.922
# 07-17 04:24:10
# 07-17 04:24:10	Start Evaluating on Evaluation Set, EPOCH 72 BATCH 1080
# 100%|██████████| 2/2 [00:00<00:00, 21.47it/s]
# 07-17 04:24:10	roc-auc: 0.924
# 07-17 04:24:10	MCC: 0.755
# 07-17 04:24:10	prc-auc: 0.938
# 07-17 04:24:10	accuracy: 0.883
# 07-17 04:24:10	F1: 0.908
# 07-17 04:24:12
# 07-17 04:24:12	Start Evaluating on Evaluation Set, EPOCH 74 BATCH 1100
# 100%|██████████| 2/2 [00:00<00:00, 21.43it/s]
# 07-17 04:24:12	roc-auc: 0.791
# 07-17 04:24:12	MCC: 0.328
# 07-17 04:24:12	prc-auc: 0.822
# 07-17 04:24:12	accuracy: 0.631
# 07-17 04:24:12	F1: 0.627
# 07-17 04:24:12	Model not improve for 1 Epochs.
# 07-17 04:24:12	Best roc-auc Now: 0.924
# 07-17 04:24:14
# 07-17 04:24:14	Start Evaluating on Evaluation Set, EPOCH 75 BATCH 1120
# 100%|██████████| 2/2 [00:00<00:00, 20.15it/s]
# 07-17 04:24:14	roc-auc: 0.665
# 07-17 04:24:14	MCC: -0.002
# 07-17 04:24:14	prc-auc: 0.721
# 07-17 04:24:14	accuracy: 0.398
# 07-17 04:24:14	F1: 0.046
# 07-17 04:24:14	Model not improve for 2 Epochs.
# 07-17 04:24:14	Best roc-auc Now: 0.924
# 07-17 04:24:16
# 07-17 04:24:16	Start Evaluating on Evaluation Set, EPOCH 76 BATCH 1140
# 100%|██████████| 2/2 [00:00<00:00, 19.41it/s]
# 07-17 04:24:16	roc-auc: 0.918
# 07-17 04:24:16	MCC: 0.709
# 07-17 04:24:16	prc-auc: 0.941
# 07-17 04:24:16	accuracy: 0.859
# 07-17 04:24:16	F1: 0.893
# 07-17 04:24:16	Model not improve for 3 Epochs.
# 07-17 04:24:16	Best roc-auc Now: 0.924
# 07-17 04:24:18
# 07-17 04:24:18	Start Evaluating on Evaluation Set, EPOCH 78 BATCH 1160
# 100%|██████████| 2/2 [00:00<00:00, 20.62it/s]
# 07-17 04:24:18	roc-auc: 0.900
# 07-17 04:24:18	MCC: 0.512
# 07-17 04:24:18	prc-auc: 0.897
# 07-17 04:24:18	accuracy: 0.718
# 07-17 04:24:18	F1: 0.716
# 07-17 04:24:18	Model not improve for 4 Epochs.
# 07-17 04:24:18	Best roc-auc Now: 0.924
# 07-17 04:24:20
# 07-17 04:24:20	Start Evaluating on Evaluation Set, EPOCH 79 BATCH 1180
# 100%|██████████| 2/2 [00:00<00:00, 20.97it/s]
# 07-17 04:24:20	roc-auc: 0.884
# 07-17 04:24:20	MCC: 0.568
# 07-17 04:24:20	prc-auc: 0.895
# 07-17 04:24:20	accuracy: 0.772
# 07-17 04:24:20	F1: 0.789
# 07-17 04:24:20	Model not improve for 5 Epochs.
# 07-17 04:24:20	Best roc-auc Now: 0.924
# 07-17 04:24:22
# 07-17 04:24:22	Start Evaluating on Evaluation Set, EPOCH 80 BATCH 1200
# 100%|██████████| 2/2 [00:00<00:00, 21.77it/s]
# 07-17 04:24:22	roc-auc: 0.928
# 07-17 04:24:22	MCC: 0.727
# 07-17 04:24:22	prc-auc: 0.932
# 07-17 04:24:22	accuracy: 0.869
# 07-17 04:24:22	F1: 0.899
# 07-17 04:24:25
# 07-17 04:24:25	Start Evaluating on Evaluation Set, EPOCH 82 BATCH 1220
# 100%|██████████| 2/2 [00:00<00:00, 19.56it/s]
# 07-17 04:24:25	roc-auc: 0.904
# 07-17 04:24:25	MCC: 0.618
# 07-17 04:24:25	prc-auc: 0.929
# 07-17 04:24:25	accuracy: 0.811
# 07-17 04:24:25	F1: 0.863
# 07-17 04:24:25	Model not improve for 1 Epochs.
# 07-17 04:24:25	Best roc-auc Now: 0.928
# 07-17 04:24:27
# 07-17 04:24:27	Start Evaluating on Evaluation Set, EPOCH 83 BATCH 1240
# 100%|██████████| 2/2 [00:00<00:00, 22.19it/s]
# 07-17 04:24:27	roc-auc: 0.908
# 07-17 04:24:27	MCC: 0.658
# 07-17 04:24:27	prc-auc: 0.930
# 07-17 04:24:27	accuracy: 0.835
# 07-17 04:24:27	F1: 0.862
# 07-17 04:24:27	Model not improve for 2 Epochs.
# 07-17 04:24:27	Best roc-auc Now: 0.928
# 07-17 04:24:29
# 07-17 04:24:29	Start Evaluating on Evaluation Set, EPOCH 84 BATCH 1260
# 100%|██████████| 2/2 [00:00<00:00, 23.00it/s]
# 07-17 04:24:29	roc-auc: 0.849
# 07-17 04:24:29	MCC: 0.277
# 07-17 04:24:29	prc-auc: 0.840
# 07-17 04:24:29	accuracy: 0.544
# 07-17 04:24:29	F1: 0.434
# 07-17 04:24:29	Model not improve for 3 Epochs.
# 07-17 04:24:29	Best roc-auc Now: 0.928
# 07-17 04:24:31
# 07-17 04:24:31	Start Evaluating on Evaluation Set, EPOCH 86 BATCH 1280
# 100%|██████████| 2/2 [00:00<00:00, 19.51it/s]
# 07-17 04:24:31	roc-auc: 0.709
# 07-17 04:24:31	MCC: 0.350
# 07-17 04:24:31	prc-auc: 0.740
# 07-17 04:24:31	accuracy: 0.694
# 07-17 04:24:31	F1: 0.755
# 07-17 04:24:31	Model not improve for 4 Epochs.
# 07-17 04:24:31	Best roc-auc Now: 0.928
# 07-17 04:24:33
# 07-17 04:24:33	Start Evaluating on Evaluation Set, EPOCH 87 BATCH 1300
# 100%|██████████| 2/2 [00:00<00:00, 19.56it/s]
# 07-17 04:24:33	roc-auc: 0.913
# 07-17 04:24:33	MCC: 0.678
# 07-17 04:24:33	prc-auc: 0.909
# 07-17 04:24:33	accuracy: 0.845
# 07-17 04:24:33	F1: 0.870
# 07-17 04:24:33	Model not improve for 5 Epochs.
# 07-17 04:24:33	Best roc-auc Now: 0.928
# 07-17 04:24:35
# 07-17 04:24:35	Start Evaluating on Evaluation Set, EPOCH 88 BATCH 1320
# 100%|██████████| 2/2 [00:00<00:00, 19.27it/s]
# 07-17 04:24:35	roc-auc: 0.810
# 07-17 04:24:35	MCC: 0.487
# 07-17 04:24:35	prc-auc: 0.838
# 07-17 04:24:35	accuracy: 0.743
# 07-17 04:24:35	F1: 0.773
# 07-17 04:24:35	Model not improve for 6 Epochs.
# 07-17 04:24:35	Best roc-auc Now: 0.928
# 07-17 04:24:37
# 07-17 04:24:37	Start Evaluating on Evaluation Set, EPOCH 90 BATCH 1340
# 100%|██████████| 2/2 [00:00<00:00, 16.86it/s]
# 07-17 04:24:37	roc-auc: 0.787
# 07-17 04:24:37	MCC: 0.249
# 07-17 04:24:37	prc-auc: 0.794
# 07-17 04:24:37	accuracy: 0.583
# 07-17 04:24:37	F1: 0.561
# 07-17 04:24:37	Model not improve for 7 Epochs.
# 07-17 04:24:37	Best roc-auc Now: 0.928
# 07-17 04:24:39
# 07-17 04:24:39	Start Evaluating on Evaluation Set, EPOCH 91 BATCH 1360
# 100%|██████████| 2/2 [00:00<00:00, 19.97it/s]
# 07-17 04:24:39	roc-auc: 0.897
# 07-17 04:24:39	MCC: 0.533
# 07-17 04:24:39	prc-auc: 0.896
# 07-17 04:24:39	accuracy: 0.738
# 07-17 04:24:39	F1: 0.743
# 07-17 04:24:39	Model not improve for 8 Epochs.
# 07-17 04:24:39	Best roc-auc Now: 0.928
# 07-17 04:24:41
# 07-17 04:24:41	Start Evaluating on Evaluation Set, EPOCH 92 BATCH 1380
# 100%|██████████| 2/2 [00:00<00:00, 20.90it/s]
# 07-17 04:24:41	roc-auc: 0.850
# 07-17 04:24:41	MCC: 0.400
# 07-17 04:24:41	prc-auc: 0.853
# 07-17 04:24:41	accuracy: 0.631
# 07-17 04:24:41	F1: 0.587
# 07-17 04:24:41	Model not improve for 9 Epochs.
# 07-17 04:24:41	Best roc-auc Now: 0.928
# 07-17 04:24:43
# 07-17 04:24:43	Start Evaluating on Evaluation Set, EPOCH 94 BATCH 1400
# 100%|██████████| 2/2 [00:00<00:00, 20.78it/s]
# 07-17 04:24:43	roc-auc: 0.641
# 07-17 04:24:43	MCC: 0.069
# 07-17 04:24:43	prc-auc: 0.673
# 07-17 04:24:43	accuracy: 0.461
# 07-17 04:24:43	F1: 0.327
# 07-17 04:24:43	Model not improve for 10 Epochs.
# 07-17 04:24:43	Best roc-auc Now: 0.928
# 07-17 04:24:45
# 07-17 04:24:45	Start Evaluating on Evaluation Set, EPOCH 95 BATCH 1420
# 100%|██████████| 2/2 [00:00<00:00, 20.80it/s]
# 07-17 04:24:45	roc-auc: 0.839
# 07-17 04:24:45	MCC: 0.159
# 07-17 04:24:45	prc-auc: 0.854
# 07-17 04:24:45	accuracy: 0.451
# 07-17 04:24:45	F1: 0.199
# 07-17 04:24:45	Model not improve for 11 Epochs.
# 07-17 04:24:45	Best roc-auc Now: 0.928
# 07-17 04:24:47
# 07-17 04:24:47	Start Evaluating on Evaluation Set, EPOCH 96 BATCH 1440
# 100%|██████████| 2/2 [00:00<00:00, 23.52it/s]
# 07-17 04:24:47	roc-auc: 0.819
# 07-17 04:24:47	MCC: 0.212
# 07-17 04:24:47	prc-auc: 0.820
# 07-17 04:24:47	accuracy: 0.495
# 07-17 04:24:47	F1: 0.325
# 07-17 04:24:47	Model not improve for 12 Epochs.
# 07-17 04:24:47	Best roc-auc Now: 0.928
# 07-17 04:24:49
# 07-17 04:24:49	Start Evaluating on Evaluation Set, EPOCH 98 BATCH 1460
# 100%|██████████| 2/2 [00:00<00:00, 21.45it/s]
# 07-17 04:24:49	roc-auc: 0.905
# 07-17 04:24:49	MCC: 0.633
# 07-17 04:24:49	prc-auc: 0.925
# 07-17 04:24:49	accuracy: 0.820
# 07-17 04:24:49	F1: 0.846
# 07-17 04:24:49	Model not improve for 13 Epochs.
# 07-17 04:24:49	Best roc-auc Now: 0.928
# 07-17 04:24:51
# 07-17 04:24:51	Start Evaluating on Evaluation Set, EPOCH 99 BATCH 1480
# 100%|██████████| 2/2 [00:00<00:00, 21.18it/s]
# 07-17 04:24:51	roc-auc: 0.878
# 07-17 04:24:51	MCC: 0.519
# 07-17 04:24:51	prc-auc: 0.906
# 07-17 04:24:51	accuracy: 0.723
# 07-17 04:24:51	F1: 0.722
# 07-17 04:24:51	Model not improve for 14 Epochs.
# 07-17 04:24:51	Best roc-auc Now: 0.928
# 07-17 04:24:53
# 07-17 04:24:53	Start Evaluating on Evaluation Set, EPOCH 100 BATCH 1500
# 100%|██████████| 2/2 [00:00<00:00, 20.24it/s]
# 07-17 04:24:53	roc-auc: 0.918
# 07-17 04:24:53	MCC: 0.717
# 07-17 04:24:53	prc-auc: 0.938
# 07-17 04:24:53	accuracy: 0.864
# 07-17 04:24:53	F1: 0.887
# 07-17 04:24:53	Model not improve for 15 Epochs.
# 07-17 04:24:53	Best roc-auc Now: 0.928
# 07-17 04:24:55
# 07-17 04:24:55	Start Evaluating on Evaluation Set, EPOCH 102 BATCH 1520
# 100%|██████████| 2/2 [00:00<00:00, 21.89it/s]
# 07-17 04:24:55	roc-auc: 0.924
# 07-17 04:24:55	MCC: 0.667
# 07-17 04:24:55	prc-auc: 0.930
# 07-17 04:24:55	accuracy: 0.835
# 07-17 04:24:55	F1: 0.879
# 07-17 04:24:55	Model not improve for 16 Epochs.
# 07-17 04:24:55	Best roc-auc Now: 0.928
# 07-17 04:24:57
# 07-17 04:24:57	Start Evaluating on Evaluation Set, EPOCH 103 BATCH 1540
# 100%|██████████| 2/2 [00:00<00:00, 25.20it/s]
# 07-17 04:24:57	roc-auc: 0.829
# 07-17 04:24:57	MCC: 0.579
# 07-17 04:24:57	prc-auc: 0.839
# 07-17 04:24:57	accuracy: 0.791
# 07-17 04:24:57	F1: 0.851
# 07-17 04:24:57	Model not improve for 17 Epochs.
# 07-17 04:24:57	Best roc-auc Now: 0.928
# 07-17 04:24:59
# 07-17 04:24:59	Start Evaluating on Evaluation Set, EPOCH 104 BATCH 1560
# 100%|██████████| 2/2 [00:00<00:00, 24.70it/s]
# 07-17 04:24:59	roc-auc: 0.817
# 07-17 04:24:59	MCC: 0.523
# 07-17 04:24:59	prc-auc: 0.868
# 07-17 04:24:59	accuracy: 0.772
# 07-17 04:24:59	F1: 0.835
# 07-17 04:24:59	Model not improve for 18 Epochs.
# 07-17 04:24:59	Best roc-auc Now: 0.928
# 07-17 04:25:01
# 07-17 04:25:01	Start Evaluating on Evaluation Set, EPOCH 106 BATCH 1580
# 100%|██████████| 2/2 [00:00<00:00, 23.92it/s]
# 07-17 04:25:01	roc-auc: 0.892
# 07-17 04:25:01	MCC: 0.661
# 07-17 04:25:01	prc-auc: 0.905
# 07-17 04:25:01	accuracy: 0.840
# 07-17 04:25:01	F1: 0.872
# 07-17 04:25:01	Model not improve for 19 Epochs.
# 07-17 04:25:01	Best roc-auc Now: 0.928
# 07-17 04:25:02
# 07-17 04:25:02	Start Evaluating on Evaluation Set, EPOCH 107 BATCH 1600
# 100%|██████████| 2/2 [00:00<00:00, 26.48it/s]
# 07-17 04:25:03	roc-auc: 0.711
# 07-17 04:25:03	MCC: 0.115
# 07-17 04:25:03	prc-auc: 0.752
# 07-17 04:25:03	accuracy: 0.432
# 07-17 04:25:03	F1: 0.146
# 07-17 04:25:03	Model not improve for 20 Epochs.
# 07-17 04:25:03	Best roc-auc Now: 0.928
# 07-17 04:25:04
# 07-17 04:25:04	Start Evaluating on Evaluation Set, EPOCH 108 BATCH 1620
# 100%|██████████| 2/2 [00:00<00:00, 19.48it/s]
# 07-17 04:25:05	roc-auc: 0.758
# 07-17 04:25:05	MCC: 0.129
# 07-17 04:25:05	prc-auc: 0.750
# 07-17 04:25:05	accuracy: 0.490
# 07-17 04:25:05	F1: 0.379
# 07-17 04:25:05	Model not improve for 21 Epochs.
# 07-17 04:25:05	Best roc-auc Now: 0.928
# 07-17 04:25:07
# 07-17 04:25:07	Start Evaluating on Evaluation Set, EPOCH 110 BATCH 1640
# 100%|██████████| 2/2 [00:00<00:00, 22.05it/s]
# 07-17 04:25:07	roc-auc: 0.711
# 07-17 04:25:07	MCC: 0.276
# 07-17 04:25:07	prc-auc: 0.711
# 07-17 04:25:07	accuracy: 0.636
# 07-17 04:25:07	F1: 0.672
# 07-17 04:25:07	Model not improve for 22 Epochs.
# 07-17 04:25:07	Best roc-auc Now: 0.928
# 07-17 04:25:09
# 07-17 04:25:09	Start Evaluating on Evaluation Set, EPOCH 111 BATCH 1660
# 100%|██████████| 2/2 [00:00<00:00, 20.01it/s]
# 07-17 04:25:09	roc-auc: 0.848
# 07-17 04:25:09	MCC: 0.472
# 07-17 04:25:09	prc-auc: 0.880
# 07-17 04:25:09	accuracy: 0.704
# 07-17 04:25:09	F1: 0.705
# 07-17 04:25:09	Model not improve for 23 Epochs.
# 07-17 04:25:09	Best roc-auc Now: 0.928
# 07-17 04:25:11
# 07-17 04:25:11	Start Evaluating on Evaluation Set, EPOCH 112 BATCH 1680
# 100%|██████████| 2/2 [00:00<00:00, 20.37it/s]
# 07-17 04:25:11	roc-auc: 0.908
# 07-17 04:25:11	MCC: 0.638
# 07-17 04:25:11	prc-auc: 0.928
# 07-17 04:25:11	accuracy: 0.811
# 07-17 04:25:11	F1: 0.828
# 07-17 04:25:11	Model not improve for 24 Epochs.
# 07-17 04:25:11	Best roc-auc Now: 0.928
# 07-17 04:25:13
# 07-17 04:25:13	Start Evaluating on Evaluation Set, EPOCH 114 BATCH 1700
# 100%|██████████| 2/2 [00:00<00:00, 20.23it/s]
# 07-17 04:25:13	roc-auc: 0.917
# 07-17 04:25:13	MCC: 0.547
# 07-17 04:25:13	prc-auc: 0.937
# 07-17 04:25:13	accuracy: 0.743
# 07-17 04:25:13	F1: 0.746
# 07-17 04:25:13	Model not improve for 25 Epochs.
# 07-17 04:25:13	Best roc-auc Now: 0.928
# 07-17 04:25:15
# 07-17 04:25:15	Start Evaluating on Evaluation Set, EPOCH 115 BATCH 1720
# 100%|██████████| 2/2 [00:00<00:00, 20.03it/s]
# 07-17 04:25:15	roc-auc: 0.880
# 07-17 04:25:15	MCC: 0.533
# 07-17 04:25:15	prc-auc: 0.895
# 07-17 04:25:15	accuracy: 0.762
# 07-17 04:25:15	F1: 0.836
# 07-17 04:25:15	Model not improve for 26 Epochs.
# 07-17 04:25:15	Best roc-auc Now: 0.928
# 07-17 04:25:17
# 07-17 04:25:17	Start Evaluating on Evaluation Set, EPOCH 116 BATCH 1740
# 100%|██████████| 2/2 [00:00<00:00, 20.00it/s]
# 07-17 04:25:17	roc-auc: 0.916
# 07-17 04:25:17	MCC: 0.625
# 07-17 04:25:17	prc-auc: 0.928
# 07-17 04:25:17	accuracy: 0.796
# 07-17 04:25:17	F1: 0.809
# 07-17 04:25:17	Model not improve for 27 Epochs.
# 07-17 04:25:17	Best roc-auc Now: 0.928
# 07-17 04:25:19
# 07-17 04:25:19	Start Evaluating on Evaluation Set, EPOCH 118 BATCH 1760
# 100%|██████████| 2/2 [00:00<00:00, 21.78it/s]
# 07-17 04:25:19	roc-auc: 0.917
# 07-17 04:25:19	MCC: 0.711
# 07-17 04:25:19	prc-auc: 0.928
# 07-17 04:25:19	accuracy: 0.859
# 07-17 04:25:19	F1: 0.881
# 07-17 04:25:19	Model not improve for 28 Epochs.
# 07-17 04:25:19	Best roc-auc Now: 0.928
# 07-17 04:25:21
# 07-17 04:25:21	Start Evaluating on Evaluation Set, EPOCH 119 BATCH 1780
# 100%|██████████| 2/2 [00:00<00:00, 20.02it/s]
# 07-17 04:25:21	roc-auc: 0.886
# 07-17 04:25:21	MCC: 0.500
# 07-17 04:25:21	prc-auc: 0.922
# 07-17 04:25:21	accuracy: 0.723
# 07-17 04:25:21	F1: 0.730
# 07-17 04:25:21	Model not improve for 29 Epochs.
# 07-17 04:25:21	Best roc-auc Now: 0.928
# 07-17 04:25:23
# 07-17 04:25:23	Start Evaluating on Evaluation Set, EPOCH 120 BATCH 1800
# 100%|██████████| 2/2 [00:00<00:00, 20.32it/s]
# 07-17 04:25:23	roc-auc: 0.900
# 07-17 04:25:23	MCC: 0.499
# 07-17 04:25:23	prc-auc: 0.930
# 07-17 04:25:23	accuracy: 0.757
# 07-17 04:25:23	F1: 0.829
# 07-17 04:25:23	Model not improve for 30 Epochs.
# 07-17 04:25:23	Best roc-auc Now: 0.928
# 07-17 04:25:23	Finish Training.
# 07-17 04:25:23	Best roc-auc: 0.928
# 07-17 04:25:23	Loading pretrained parameter "encoder.attfp.init_context.project_node.0.weight".
# 07-17 04:25:23	Loading pretrained parameter "encoder.attfp.init_context.project_node.0.bias".
# 07-17 04:25:23	Loading pretrained parameter "encoder.attfp.init_context.project_edge1.0.weight".
# 07-17 04:25:23	Loading pretrained parameter "encoder.attfp.init_context.project_edge1.0.bias".
# 07-17 04:25:23	Loading pretrained parameter "encoder.attfp.init_context.project_edge2.1.weight".
# 07-17 04:25:23	Loading pretrained parameter "encoder.attfp.init_context.project_edge2.1.bias".
# 07-17 04:25:23	Loading pretrained parameter "encoder.attfp.init_context.attentive_gru.edge_transform.1.weight".
# 07-17 04:25:23	Loading pretrained parameter "encoder.attfp.init_context.attentive_gru.edge_transform.1.bias".
# 07-17 04:25:23	Loading pretrained parameter "encoder.attfp.init_context.attentive_gru.gru.weight_ih".
# 07-17 04:25:23	Loading pretrained parameter "encoder.attfp.init_context.attentive_gru.gru.weight_hh".
# 07-17 04:25:23	Loading pretrained parameter "encoder.attfp.init_context.attentive_gru.gru.bias_ih".
# 07-17 04:25:23	Loading pretrained parameter "encoder.attfp.init_context.attentive_gru.gru.bias_hh".
# 07-17 04:25:23	Loading pretrained parameter "encoder.attfp.gnn_layers.0.project_edge.1.weight".
# 07-17 04:25:23	Loading pretrained parameter "encoder.attfp.gnn_layers.0.project_edge.1.bias".
# 07-17 04:25:23	Loading pretrained parameter "encoder.attfp.gnn_layers.0.attentive_gru.project_node.1.weight".
# 07-17 04:25:23	Loading pretrained parameter "encoder.attfp.gnn_layers.0.attentive_gru.project_node.1.bias".
# 07-17 04:25:23	Loading pretrained parameter "encoder.attfp.gnn_layers.0.attentive_gru.gru.weight_ih".
# 07-17 04:25:23	Loading pretrained parameter "encoder.attfp.gnn_layers.0.attentive_gru.gru.weight_hh".
# 07-17 04:25:23	Loading pretrained parameter "encoder.attfp.gnn_layers.0.attentive_gru.gru.bias_ih".
# 07-17 04:25:23	Loading pretrained parameter "encoder.attfp.gnn_layers.0.attentive_gru.gru.bias_hh".
# 07-17 04:25:23	Loading pretrained parameter "encoder.attfp.gnn_layers.1.project_edge.1.weight".
# 07-17 04:25:23	Loading pretrained parameter "encoder.attfp.gnn_layers.1.project_edge.1.bias".
# 07-17 04:25:23	Loading pretrained parameter "encoder.attfp.gnn_layers.1.attentive_gru.project_node.1.weight".
# 07-17 04:25:23	Loading pretrained parameter "encoder.attfp.gnn_layers.1.attentive_gru.project_node.1.bias".
# 07-17 04:25:23	Loading pretrained parameter "encoder.attfp.gnn_layers.1.attentive_gru.gru.weight_ih".
# 07-17 04:25:23	Loading pretrained parameter "encoder.attfp.gnn_layers.1.attentive_gru.gru.weight_hh".
# 07-17 04:25:23	Loading pretrained parameter "encoder.attfp.gnn_layers.1.attentive_gru.gru.bias_ih".
# 07-17 04:25:23	Loading pretrained parameter "encoder.attfp.gnn_layers.1.attentive_gru.gru.bias_hh".
# 07-17 04:25:23	Loading pretrained parameter "encoder.readout.readouts.0.compute_logits.0.weight".
# 07-17 04:25:23	Loading pretrained parameter "encoder.readout.readouts.0.compute_logits.0.bias".
# 07-17 04:25:23	Loading pretrained parameter "encoder.readout.readouts.0.project_nodes.1.weight".
# 07-17 04:25:23	Loading pretrained parameter "encoder.readout.readouts.0.project_nodes.1.bias".
# 07-17 04:25:23	Loading pretrained parameter "encoder.readout.readouts.0.gru.weight_ih".
# 07-17 04:25:23	Loading pretrained parameter "encoder.readout.readouts.0.gru.weight_hh".
# 07-17 04:25:23	Loading pretrained parameter "encoder.readout.readouts.0.gru.bias_ih".
# 07-17 04:25:23	Loading pretrained parameter "encoder.readout.readouts.0.gru.bias_hh".
# 07-17 04:25:23	Loading pretrained parameter "encoder.readout.readouts.1.compute_logits.0.weight".
# 07-17 04:25:23	Loading pretrained parameter "encoder.readout.readouts.1.compute_logits.0.bias".
# 07-17 04:25:23	Loading pretrained parameter "encoder.readout.readouts.1.project_nodes.1.weight".
# 07-17 04:25:23	Loading pretrained parameter "encoder.readout.readouts.1.project_nodes.1.bias".
# 07-17 04:25:23	Loading pretrained parameter "encoder.readout.readouts.1.gru.weight_ih".
# 07-17 04:25:23	Loading pretrained parameter "encoder.readout.readouts.1.gru.weight_hh".
# 07-17 04:25:23	Loading pretrained parameter "encoder.readout.readouts.1.gru.bias_ih".
# 07-17 04:25:23	Loading pretrained parameter "encoder.readout.readouts.1.gru.bias_hh".
# 07-17 04:25:23	Loading pretrained parameter "ffn.0.weight".
# 07-17 04:25:23	Loading pretrained parameter "ffn.0.bias".
# 07-17 04:25:23	Loading pretrained parameter "ffn.3.weight".
# 07-17 04:25:23	Loading pretrained parameter "ffn.3.bias".
# 07-17 04:25:23	Loading pretrained parameter "ffn.6.weight".
# 07-17 04:25:23	Loading pretrained parameter "ffn.6.bias".
# 07-17 04:25:23	Loading pretrained parameter "density_estimation.0.mean".
# 07-17 04:25:23	Loading pretrained parameter "density_estimation.0.cov".
# 07-17 04:25:23	Loading pretrained parameter "density_estimation.0.transforms.0.arn.permutation".
# 07-17 04:25:23	Loading pretrained parameter "density_estimation.0.transforms.0.arn.layers.0.weight".
# 07-17 04:25:23	Loading pretrained parameter "density_estimation.0.transforms.0.arn.layers.0.bias".
# 07-17 04:25:23	Loading pretrained parameter "density_estimation.0.transforms.0.arn.layers.0.mask".
# 07-17 04:25:23	Loading pretrained parameter "density_estimation.0.transforms.0.arn.layers.1.weight".
# 07-17 04:25:23	Loading pretrained parameter "density_estimation.0.transforms.0.arn.layers.1.bias".
# 07-17 04:25:23	Loading pretrained parameter "density_estimation.0.transforms.0.arn.layers.1.mask".
# 07-17 04:25:23	Loading pretrained parameter "density_estimation.0.transforms.0.arn.layers.2.weight".
# 07-17 04:25:23	Loading pretrained parameter "density_estimation.0.transforms.0.arn.layers.2.bias".
# 07-17 04:25:23	Loading pretrained parameter "density_estimation.0.transforms.0.arn.layers.2.mask".
# 07-17 04:25:23	Loading pretrained parameter "density_estimation.0.transforms.1.arn.permutation".
# 07-17 04:25:23	Loading pretrained parameter "density_estimation.0.transforms.1.arn.layers.0.weight".
# 07-17 04:25:23	Loading pretrained parameter "density_estimation.0.transforms.1.arn.layers.0.bias".
# 07-17 04:25:23	Loading pretrained parameter "density_estimation.0.transforms.1.arn.layers.0.mask".
# 07-17 04:25:23	Loading pretrained parameter "density_estimation.0.transforms.1.arn.layers.1.weight".
# 07-17 04:25:23	Loading pretrained parameter "density_estimation.0.transforms.1.arn.layers.1.bias".
# 07-17 04:25:23	Loading pretrained parameter "density_estimation.0.transforms.1.arn.layers.1.mask".
# 07-17 04:25:23	Loading pretrained parameter "density_estimation.0.transforms.1.arn.layers.2.weight".
# 07-17 04:25:23	Loading pretrained parameter "density_estimation.0.transforms.1.arn.layers.2.bias".
# 07-17 04:25:23	Loading pretrained parameter "density_estimation.0.transforms.1.arn.layers.2.mask".
# 07-17 04:25:23	Loading pretrained parameter "density_estimation.1.mean".
# 07-17 04:25:23	Loading pretrained parameter "density_estimation.1.cov".
# 07-17 04:25:23	Loading pretrained parameter "density_estimation.1.transforms.0.arn.permutation".
# 07-17 04:25:23	Loading pretrained parameter "density_estimation.1.transforms.0.arn.layers.0.weight".
# 07-17 04:25:23	Loading pretrained parameter "density_estimation.1.transforms.0.arn.layers.0.bias".
# 07-17 04:25:23	Loading pretrained parameter "density_estimation.1.transforms.0.arn.layers.0.mask".
# 07-17 04:25:23	Loading pretrained parameter "density_estimation.1.transforms.0.arn.layers.1.weight".
# 07-17 04:25:23	Loading pretrained parameter "density_estimation.1.transforms.0.arn.layers.1.bias".
# 07-17 04:25:23	Loading pretrained parameter "density_estimation.1.transforms.0.arn.layers.1.mask".
# 07-17 04:25:23	Loading pretrained parameter "density_estimation.1.transforms.0.arn.layers.2.weight".
# 07-17 04:25:23	Loading pretrained parameter "density_estimation.1.transforms.0.arn.layers.2.bias".
# 07-17 04:25:23	Loading pretrained parameter "density_estimation.1.transforms.0.arn.layers.2.mask".
# 07-17 04:25:23	Loading pretrained parameter "density_estimation.1.transforms.1.arn.permutation".
# 07-17 04:25:23	Loading pretrained parameter "density_estimation.1.transforms.1.arn.layers.0.weight".
# 07-17 04:25:23	Loading pretrained parameter "density_estimation.1.transforms.1.arn.layers.0.bias".
# 07-17 04:25:23	Loading pretrained parameter "density_estimation.1.transforms.1.arn.layers.0.mask".
# 07-17 04:25:23	Loading pretrained parameter "density_estimation.1.transforms.1.arn.layers.1.weight".
# 07-17 04:25:23	Loading pretrained parameter "density_estimation.1.transforms.1.arn.layers.1.bias".
# 07-17 04:25:23	Loading pretrained parameter "density_estimation.1.transforms.1.arn.layers.1.mask".
# 07-17 04:25:23	Loading pretrained parameter "density_estimation.1.transforms.1.arn.layers.2.weight".
# 07-17 04:25:23	Loading pretrained parameter "density_estimation.1.transforms.1.arn.layers.2.bias".
# 07-17 04:25:23	Loading pretrained parameter "density_estimation.1.transforms.1.arn.layers.2.mask".
# 07-17 04:25:23	Loading pretrained parameter "batch_norm.weight".
# 07-17 04:25:23	Loading pretrained parameter "batch_norm.bias".
# 07-17 04:25:23	Loading pretrained parameter "batch_norm.running_mean".
# 07-17 04:25:23	Loading pretrained parameter "batch_norm.running_var".
# 07-17 04:25:23	Loading pretrained parameter "batch_norm.num_batches_tracked".
# 100%|██████████| 2/2 [00:00<00:00, 20.29it/s]
# 100%|██████████| 2/2 [00:00<00:00, 21.01it/s]
# 100%|██████████| 2/2 [00:00<00:00, 19.60it/s]
# 100%|██████████| 2/2 [00:00<00:00, 24.30it/s]
# 1850it [00:04, 373.24it/s]
# 206it [00:00, 358.82it/s]
# 152it [00:00, 333.37it/s]
# 07-17 04:25:30	Training 0th model.
# 07-17 04:26:55
# 07-17 04:26:55	Start Evaluating on Evaluation Set, EPOCH 60 BATCH 900
# 100%|██████████| 2/2 [00:00<00:00, 20.01it/s]
# 07-17 04:26:55	roc-auc: 0.777
# 07-17 04:26:55	MCC: 0.285
# 07-17 04:26:55	prc-auc: 0.841
# 07-17 04:26:55	accuracy: 0.534
# 07-17 04:26:55	F1: 0.400
# 07-17 04:26:57
# 07-17 04:26:57	Start Evaluating on Evaluation Set, EPOCH 62 BATCH 920
# 100%|██████████| 2/2 [00:00<00:00, 21.54it/s]
# 07-17 04:26:57	roc-auc: 0.833
# 07-17 04:26:57	MCC: 0.484
# 07-17 04:26:57	prc-auc: 0.875
# 07-17 04:26:57	accuracy: 0.757
# 07-17 04:26:57	F1: 0.806
# 07-17 04:27:00
# 07-17 04:27:00	Start Evaluating on Evaluation Set, EPOCH 63 BATCH 940
# 100%|██████████| 2/2 [00:00<00:00, 20.92it/s]
# 07-17 04:27:00	roc-auc: 0.862
# 07-17 04:27:00	MCC: 0.516
# 07-17 04:27:00	prc-auc: 0.910
# 07-17 04:27:00	accuracy: 0.738
# 07-17 04:27:00	F1: 0.750
# 07-17 04:27:02
# 07-17 04:27:02	Start Evaluating on Evaluation Set, EPOCH 64 BATCH 960
# 100%|██████████| 2/2 [00:00<00:00, 20.44it/s]
# 07-17 04:27:02	roc-auc: 0.652
# 07-17 04:27:02	MCC: 0.080
# 07-17 04:27:02	prc-auc: 0.739
# 07-17 04:27:02	accuracy: 0.403
# 07-17 04:27:02	F1: 0.031
# 07-17 04:27:02	Model not improve for 1 Epochs.
# 07-17 04:27:02	Best roc-auc Now: 0.862
# 07-17 04:27:04
# 07-17 04:27:04	Start Evaluating on Evaluation Set, EPOCH 66 BATCH 980
# 100%|██████████| 2/2 [00:00<00:00, 19.29it/s]
# 07-17 04:27:04	roc-auc: 0.835
# 07-17 04:27:04	MCC: 0.551
# 07-17 04:27:04	prc-auc: 0.901
# 07-17 04:27:04	accuracy: 0.757
# 07-17 04:27:04	F1: 0.771
# 07-17 04:27:04	Model not improve for 2 Epochs.
# 07-17 04:27:04	Best roc-auc Now: 0.862
# 07-17 04:27:06
# 07-17 04:27:06	Start Evaluating on Evaluation Set, EPOCH 67 BATCH 1000
# 100%|██████████| 2/2 [00:00<00:00, 20.11it/s]
# 07-17 04:27:06	roc-auc: 0.804
# 07-17 04:27:06	MCC: 0.255
# 07-17 04:27:06	prc-auc: 0.795
# 07-17 04:27:06	accuracy: 0.553
# 07-17 04:27:06	F1: 0.477
# 07-17 04:27:06	Model not improve for 3 Epochs.
# 07-17 04:27:06	Best roc-auc Now: 0.862
# 07-17 04:27:08
# 07-17 04:27:08	Start Evaluating on Evaluation Set, EPOCH 68 BATCH 1020
# 100%|██████████| 2/2 [00:00<00:00, 20.97it/s]
# 07-17 04:27:08	roc-auc: 0.831
# 07-17 04:27:08	MCC: 0.527
# 07-17 04:27:08	prc-auc: 0.872
# 07-17 04:27:08	accuracy: 0.757
# 07-17 04:27:08	F1: 0.781
# 07-17 04:27:08	Model not improve for 4 Epochs.
# 07-17 04:27:08	Best roc-auc Now: 0.862
# 07-17 04:27:10
# 07-17 04:27:10	Start Evaluating on Evaluation Set, EPOCH 70 BATCH 1040
# 100%|██████████| 2/2 [00:00<00:00, 20.21it/s]
# 07-17 04:27:10	roc-auc: 0.839
# 07-17 04:27:10	MCC: 0.579
# 07-17 04:27:10	prc-auc: 0.885
# 07-17 04:27:10	accuracy: 0.782
# 07-17 04:27:10	F1: 0.802
# 07-17 04:27:10	Model not improve for 5 Epochs.
# 07-17 04:27:10	Best roc-auc Now: 0.862
# 07-17 04:27:12
# 07-17 04:27:12	Start Evaluating on Evaluation Set, EPOCH 71 BATCH 1060
# 100%|██████████| 2/2 [00:00<00:00, 20.86it/s]
# 07-17 04:27:13	roc-auc: 0.740
# 07-17 04:27:13	MCC: 0.172
# 07-17 04:27:13	prc-auc: 0.798
# 07-17 04:27:13	accuracy: 0.437
# 07-17 04:27:13	F1: 0.134
# 07-17 04:27:13	Model not improve for 6 Epochs.
# 07-17 04:27:13	Best roc-auc Now: 0.862
# 07-17 04:27:14
# 07-17 04:27:15	Start Evaluating on Evaluation Set, EPOCH 72 BATCH 1080
# 100%|██████████| 2/2 [00:00<00:00, 19.49it/s]
# 07-17 04:27:15	roc-auc: 0.885
# 07-17 04:27:15	MCC: 0.586
# 07-17 04:27:15	prc-auc: 0.925
# 07-17 04:27:15	accuracy: 0.801
# 07-17 04:27:15	F1: 0.834
# 07-17 04:27:17
# 07-17 04:27:17	Start Evaluating on Evaluation Set, EPOCH 74 BATCH 1100
# 100%|██████████| 2/2 [00:00<00:00, 30.47it/s]
# 07-17 04:27:17	roc-auc: 0.720
# 07-17 04:27:17	MCC: 0.115
# 07-17 04:27:17	prc-auc: 0.780
# 07-17 04:27:17	accuracy: 0.432
# 07-17 04:27:17	F1: 0.146
# 07-17 04:27:17	Model not improve for 1 Epochs.
# 07-17 04:27:17	Best roc-auc Now: 0.885
# 07-17 04:27:19
# 07-17 04:27:19	Start Evaluating on Evaluation Set, EPOCH 75 BATCH 1120
# 100%|██████████| 2/2 [00:00<00:00, 19.53it/s]
# 07-17 04:27:19	roc-auc: 0.835
# 07-17 04:27:19	MCC: 0.445
# 07-17 04:27:19	prc-auc: 0.878
# 07-17 04:27:19	accuracy: 0.694
# 07-17 04:27:19	F1: 0.699
# 07-17 04:27:19	Model not improve for 2 Epochs.
# 07-17 04:27:19	Best roc-auc Now: 0.885
# 07-17 04:27:21
# 07-17 04:27:21	Start Evaluating on Evaluation Set, EPOCH 76 BATCH 1140
# 100%|██████████| 2/2 [00:00<00:00, 22.70it/s]
# 07-17 04:27:21	roc-auc: 0.868
# 07-17 04:27:21	MCC: 0.520
# 07-17 04:27:21	prc-auc: 0.912
# 07-17 04:27:21	accuracy: 0.748
# 07-17 04:27:21	F1: 0.766
# 07-17 04:27:21	Model not improve for 3 Epochs.
# 07-17 04:27:21	Best roc-auc Now: 0.885
# 07-17 04:27:23
# 07-17 04:27:23	Start Evaluating on Evaluation Set, EPOCH 78 BATCH 1160
# 100%|██████████| 2/2 [00:00<00:00, 20.61it/s]
# 07-17 04:27:23	roc-auc: 0.800
# 07-17 04:27:23	MCC: 0.452
# 07-17 04:27:23	prc-auc: 0.834
# 07-17 04:27:23	accuracy: 0.718
# 07-17 04:27:23	F1: 0.743
# 07-17 04:27:23	Model not improve for 4 Epochs.
# 07-17 04:27:23	Best roc-auc Now: 0.885
# 07-17 04:27:25
# 07-17 04:27:25	Start Evaluating on Evaluation Set, EPOCH 79 BATCH 1180
# 100%|██████████| 2/2 [00:00<00:00, 21.28it/s]
# 07-17 04:27:25	roc-auc: 0.731
# 07-17 04:27:25	MCC: 0.209
# 07-17 04:27:25	prc-auc: 0.819
# 07-17 04:27:25	accuracy: 0.456
# 07-17 04:27:25	F1: 0.188
# 07-17 04:27:25	Model not improve for 5 Epochs.
# 07-17 04:27:25	Best roc-auc Now: 0.885
# 07-17 04:27:27
# 07-17 04:27:27	Start Evaluating on Evaluation Set, EPOCH 80 BATCH 1200
# 100%|██████████| 2/2 [00:00<00:00, 19.09it/s]
# 07-17 04:27:27	roc-auc: 0.759
# 07-17 04:27:27	MCC: 0.509
# 07-17 04:27:27	prc-auc: 0.798
# 07-17 04:27:27	accuracy: 0.757
# 07-17 04:27:27	F1: 0.831
# 07-17 04:27:27	Model not improve for 6 Epochs.
# 07-17 04:27:27	Best roc-auc Now: 0.885
# 07-17 04:27:29
# 07-17 04:27:29	Start Evaluating on Evaluation Set, EPOCH 82 BATCH 1220
# 100%|██████████| 2/2 [00:00<00:00, 20.77it/s]
# 07-17 04:27:29	roc-auc: 0.706
# 07-17 04:27:29	MCC: 0.232
# 07-17 04:27:29	prc-auc: 0.778
# 07-17 04:27:29	accuracy: 0.500
# 07-17 04:27:29	F1: 0.327
# 07-17 04:27:29	Model not improve for 7 Epochs.
# 07-17 04:27:29	Best roc-auc Now: 0.885
# 07-17 04:27:31
# 07-17 04:27:31	Start Evaluating on Evaluation Set, EPOCH 83 BATCH 1240
# 100%|██████████| 2/2 [00:00<00:00, 20.91it/s]
# 07-17 04:27:31	roc-auc: 0.836
# 07-17 04:27:31	MCC: 0.485
# 07-17 04:27:31	prc-auc: 0.894
# 07-17 04:27:31	accuracy: 0.699
# 07-17 04:27:31	F1: 0.690
# 07-17 04:27:31	Model not improve for 8 Epochs.
# 07-17 04:27:31	Best roc-auc Now: 0.885
# 07-17 04:27:33
# 07-17 04:27:33	Start Evaluating on Evaluation Set, EPOCH 84 BATCH 1260
# 100%|██████████| 2/2 [00:00<00:00, 21.21it/s]
# 07-17 04:27:33	roc-auc: 0.695
# 07-17 04:27:33	MCC: 0.115
# 07-17 04:27:33	prc-auc: 0.744
# 07-17 04:27:33	accuracy: 0.432
# 07-17 04:27:33	F1: 0.146
# 07-17 04:27:33	Model not improve for 9 Epochs.
# 07-17 04:27:33	Best roc-auc Now: 0.885
# 07-17 04:27:35
# 07-17 04:27:35	Start Evaluating on Evaluation Set, EPOCH 86 BATCH 1280
# 100%|██████████| 2/2 [00:00<00:00, 20.10it/s]
# 07-17 04:27:35	roc-auc: 0.716
# 07-17 04:27:35	MCC: 0.056
# 07-17 04:27:35	prc-auc: 0.796
# 07-17 04:27:35	accuracy: 0.398
# 07-17 04:27:35	F1: 0.016
# 07-17 04:27:35	Model not improve for 10 Epochs.
# 07-17 04:27:35	Best roc-auc Now: 0.885
# 07-17 04:27:37
# 07-17 04:27:37	Start Evaluating on Evaluation Set, EPOCH 87 BATCH 1300
# 100%|██████████| 2/2 [00:00<00:00, 20.70it/s]
# 07-17 04:27:37	roc-auc: 0.815
# 07-17 04:27:37	MCC: 0.447
# 07-17 04:27:37	prc-auc: 0.877
# 07-17 04:27:37	accuracy: 0.718
# 07-17 04:27:37	F1: 0.746
# 07-17 04:27:37	Model not improve for 11 Epochs.
# 07-17 04:27:37	Best roc-auc Now: 0.885
# 07-17 04:27:39
# 07-17 04:27:39	Start Evaluating on Evaluation Set, EPOCH 88 BATCH 1320
# 100%|██████████| 2/2 [00:00<00:00, 21.95it/s]
# 07-17 04:27:39	roc-auc: 0.830
# 07-17 04:27:39	MCC: 0.483
# 07-17 04:27:39	prc-auc: 0.851
# 07-17 04:27:39	accuracy: 0.743
# 07-17 04:27:39	F1: 0.774
# 07-17 04:27:39	Model not improve for 12 Epochs.
# 07-17 04:27:39	Best roc-auc Now: 0.885
# 07-17 04:27:41
# 07-17 04:27:41	Start Evaluating on Evaluation Set, EPOCH 90 BATCH 1340
# 100%|██████████| 2/2 [00:00<00:00, 19.61it/s]
# 07-17 04:27:41	roc-auc: 0.750
# 07-17 04:27:41	MCC: 0.283
# 07-17 04:27:41	prc-auc: 0.837
# 07-17 04:27:41	accuracy: 0.515
# 07-17 04:27:41	F1: 0.342
# 07-17 04:27:41	Model not improve for 13 Epochs.
# 07-17 04:27:41	Best roc-auc Now: 0.885
# 07-17 04:27:43
# 07-17 04:27:43	Start Evaluating on Evaluation Set, EPOCH 91 BATCH 1360
# 100%|██████████| 2/2 [00:00<00:00, 20.58it/s]
# 07-17 04:27:43	roc-auc: 0.853
# 07-17 04:27:43	MCC: 0.534
# 07-17 04:27:43	prc-auc: 0.885
# 07-17 04:27:43	accuracy: 0.743
# 07-17 04:27:43	F1: 0.751
# 07-17 04:27:43	Model not improve for 14 Epochs.
# 07-17 04:27:43	Best roc-auc Now: 0.885
# 07-17 04:27:45
# 07-17 04:27:45	Start Evaluating on Evaluation Set, EPOCH 92 BATCH 1380
# 100%|██████████| 2/2 [00:00<00:00, 21.09it/s]
# 07-17 04:27:45	roc-auc: 0.823
# 07-17 04:27:45	MCC: 0.534
# 07-17 04:27:45	prc-auc: 0.868
# 07-17 04:27:45	accuracy: 0.782
# 07-17 04:27:45	F1: 0.834
# 07-17 04:27:45	Model not improve for 15 Epochs.
# 07-17 04:27:45	Best roc-auc Now: 0.885
# 07-17 04:27:47
# 07-17 04:27:47	Start Evaluating on Evaluation Set, EPOCH 94 BATCH 1400
# 100%|██████████| 2/2 [00:00<00:00, 19.54it/s]
# 07-17 04:27:48	roc-auc: 0.852
# 07-17 04:27:48	MCC: 0.463
# 07-17 04:27:48	prc-auc: 0.896
# 07-17 04:27:48	accuracy: 0.733
# 07-17 04:27:48	F1: 0.766
# 07-17 04:27:48	Model not improve for 16 Epochs.
# 07-17 04:27:48	Best roc-auc Now: 0.885
# 07-17 04:27:50
# 07-17 04:27:50	Start Evaluating on Evaluation Set, EPOCH 95 BATCH 1420
# 100%|██████████| 2/2 [00:00<00:00, 24.93it/s]
# 07-17 04:27:50	roc-auc: 0.867
# 07-17 04:27:50	MCC: 0.523
# 07-17 04:27:50	prc-auc: 0.911
# 07-17 04:27:50	accuracy: 0.762
# 07-17 04:27:50	F1: 0.791
# 07-17 04:27:50	Model not improve for 17 Epochs.
# 07-17 04:27:50	Best roc-auc Now: 0.885
# 07-17 04:27:52
# 07-17 04:27:52	Start Evaluating on Evaluation Set, EPOCH 96 BATCH 1440
# 100%|██████████| 2/2 [00:00<00:00, 20.12it/s]
# 07-17 04:27:52	roc-auc: 0.826
# 07-17 04:27:52	MCC: 0.523
# 07-17 04:27:52	prc-auc: 0.882
# 07-17 04:27:52	accuracy: 0.762
# 07-17 04:27:52	F1: 0.791
# 07-17 04:27:52	Model not improve for 18 Epochs.
# 07-17 04:27:52	Best roc-auc Now: 0.885
# 07-17 04:27:54
# 07-17 04:27:54	Start Evaluating on Evaluation Set, EPOCH 98 BATCH 1460
# 100%|██████████| 2/2 [00:00<00:00, 20.65it/s]
# 07-17 04:27:54	roc-auc: 0.848
# 07-17 04:27:54	MCC: 0.619
# 07-17 04:27:54	prc-auc: 0.875
# 07-17 04:27:54	accuracy: 0.820
# 07-17 04:27:54	F1: 0.856
# 07-17 04:27:54	Model not improve for 19 Epochs.
# 07-17 04:27:54	Best roc-auc Now: 0.885
# 07-17 04:27:56
# 07-17 04:27:56	Start Evaluating on Evaluation Set, EPOCH 99 BATCH 1480
# 100%|██████████| 2/2 [00:00<00:00, 20.17it/s]
# 07-17 04:27:56	roc-auc: 0.860
# 07-17 04:27:56	MCC: 0.609
# 07-17 04:27:56	prc-auc: 0.890
# 07-17 04:27:56	accuracy: 0.816
# 07-17 04:27:56	F1: 0.853
# 07-17 04:27:56	Model not improve for 20 Epochs.
# 07-17 04:27:56	Best roc-auc Now: 0.885
# 07-17 04:27:58
# 07-17 04:27:58	Start Evaluating on Evaluation Set, EPOCH 100 BATCH 1500
# 100%|██████████| 2/2 [00:00<00:00, 22.15it/s]
# 07-17 04:27:58	roc-auc: 0.692
# 07-17 04:27:58	MCC: 0.324
# 07-17 04:27:58	prc-auc: 0.802
# 07-17 04:27:58	accuracy: 0.544
# 07-17 04:27:58	F1: 0.405
# 07-17 04:27:58	Model not improve for 21 Epochs.
# 07-17 04:27:58	Best roc-auc Now: 0.885
# 07-17 04:28:00
# 07-17 04:28:00	Start Evaluating on Evaluation Set, EPOCH 102 BATCH 1520
# 100%|██████████| 2/2 [00:00<00:00, 20.93it/s]
# 07-17 04:28:00	roc-auc: 0.750
# 07-17 04:28:00	MCC: 0.420
# 07-17 04:28:00	prc-auc: 0.843
# 07-17 04:28:00	accuracy: 0.646
# 07-17 04:28:00	F1: 0.610
# 07-17 04:28:00	Model not improve for 22 Epochs.
# 07-17 04:28:00	Best roc-auc Now: 0.885
# 07-17 04:28:02
# 07-17 04:28:02	Start Evaluating on Evaluation Set, EPOCH 103 BATCH 1540
# 100%|██████████| 2/2 [00:00<00:00, 20.90it/s]
# 07-17 04:28:02	roc-auc: 0.850
# 07-17 04:28:02	MCC: 0.523
# 07-17 04:28:02	prc-auc: 0.902
# 07-17 04:28:02	accuracy: 0.752
# 07-17 04:28:02	F1: 0.773
# 07-17 04:28:02	Model not improve for 23 Epochs.
# 07-17 04:28:02	Best roc-auc Now: 0.885
# 07-17 04:28:04
# 07-17 04:28:04	Start Evaluating on Evaluation Set, EPOCH 104 BATCH 1560
# 100%|██████████| 2/2 [00:00<00:00, 20.64it/s]
# 07-17 04:28:04	roc-auc: 0.882
# 07-17 04:28:04	MCC: 0.623
# 07-17 04:28:04	prc-auc: 0.920
# 07-17 04:28:04	accuracy: 0.820
# 07-17 04:28:04	F1: 0.853
# 07-17 04:28:04	Model not improve for 24 Epochs.
# 07-17 04:28:04	Best roc-auc Now: 0.885
# 07-17 04:28:06
# 07-17 04:28:06	Start Evaluating on Evaluation Set, EPOCH 106 BATCH 1580
# 100%|██████████| 2/2 [00:00<00:00, 20.47it/s]
# 07-17 04:28:06	roc-auc: 0.803
# 07-17 04:28:06	MCC: 0.389
# 07-17 04:28:06	prc-auc: 0.870
# 07-17 04:28:06	accuracy: 0.650
# 07-17 04:28:06	F1: 0.636
# 07-17 04:28:06	Model not improve for 25 Epochs.
# 07-17 04:28:06	Best roc-auc Now: 0.885
# 07-17 04:28:08
# 07-17 04:28:08	Start Evaluating on Evaluation Set, EPOCH 107 BATCH 1600
# 100%|██████████| 2/2 [00:00<00:00, 22.69it/s]
# 07-17 04:28:08	roc-auc: 0.848
# 07-17 04:28:08	MCC: 0.622
# 07-17 04:28:08	prc-auc: 0.877
# 07-17 04:28:08	accuracy: 0.816
# 07-17 04:28:08	F1: 0.843
# 07-17 04:28:08	Model not improve for 26 Epochs.
# 07-17 04:28:08	Best roc-auc Now: 0.885
# 07-17 04:28:10
# 07-17 04:28:10	Start Evaluating on Evaluation Set, EPOCH 108 BATCH 1620
# 100%|██████████| 2/2 [00:00<00:00, 21.40it/s]
# 07-17 04:28:10	roc-auc: 0.832
# 07-17 04:28:10	MCC: 0.586
# 07-17 04:28:10	prc-auc: 0.842
# 07-17 04:28:10	accuracy: 0.801
# 07-17 04:28:10	F1: 0.834
# 07-17 04:28:10	Model not improve for 27 Epochs.
# 07-17 04:28:10	Best roc-auc Now: 0.885
# 07-17 04:28:12
# 07-17 04:28:12	Start Evaluating on Evaluation Set, EPOCH 110 BATCH 1640
# 100%|██████████| 2/2 [00:00<00:00, 21.30it/s]
# 07-17 04:28:12	roc-auc: 0.822
# 07-17 04:28:12	MCC: 0.543
# 07-17 04:28:12	prc-auc: 0.830
# 07-17 04:28:12	accuracy: 0.772
# 07-17 04:28:12	F1: 0.800
# 07-17 04:28:12	Model not improve for 28 Epochs.
# 07-17 04:28:12	Best roc-auc Now: 0.885
# 07-17 04:28:14
# 07-17 04:28:14	Start Evaluating on Evaluation Set, EPOCH 111 BATCH 1660
# 100%|██████████| 2/2 [00:00<00:00, 20.68it/s]
# 07-17 04:28:15	roc-auc: 0.833
# 07-17 04:28:15	MCC: 0.473
# 07-17 04:28:15	prc-auc: 0.888
# 07-17 04:28:15	accuracy: 0.709
# 07-17 04:28:15	F1: 0.714
# 07-17 04:28:15	Model not improve for 29 Epochs.
# 07-17 04:28:15	Best roc-auc Now: 0.885
# 07-17 04:28:17
# 07-17 04:28:17	Start Evaluating on Evaluation Set, EPOCH 112 BATCH 1680
# 100%|██████████| 2/2 [00:00<00:00, 20.81it/s]
# 07-17 04:28:17	roc-auc: 0.809
# 07-17 04:28:17	MCC: 0.608
# 07-17 04:28:17	prc-auc: 0.793
# 07-17 04:28:17	accuracy: 0.816
# 07-17 04:28:17	F1: 0.855
# 07-17 04:28:17	Model not improve for 30 Epochs.
# 07-17 04:28:17	Best roc-auc Now: 0.885
# 07-17 04:28:17	Finish Training.
# 07-17 04:28:17	Best roc-auc: 0.885
# 07-17 04:28:17	Loading pretrained parameter "encoder.attfp.init_context.project_node.0.weight".
# 07-17 04:28:17	Loading pretrained parameter "encoder.attfp.init_context.project_node.0.bias".
# 07-17 04:28:17	Loading pretrained parameter "encoder.attfp.init_context.project_edge1.0.weight".
# 07-17 04:28:17	Loading pretrained parameter "encoder.attfp.init_context.project_edge1.0.bias".
# 07-17 04:28:17	Loading pretrained parameter "encoder.attfp.init_context.project_edge2.1.weight".
# 07-17 04:28:17	Loading pretrained parameter "encoder.attfp.init_context.project_edge2.1.bias".
# 07-17 04:28:17	Loading pretrained parameter "encoder.attfp.init_context.attentive_gru.edge_transform.1.weight".
# 07-17 04:28:17	Loading pretrained parameter "encoder.attfp.init_context.attentive_gru.edge_transform.1.bias".
# 07-17 04:28:17	Loading pretrained parameter "encoder.attfp.init_context.attentive_gru.gru.weight_ih".
# 07-17 04:28:17	Loading pretrained parameter "encoder.attfp.init_context.attentive_gru.gru.weight_hh".
# 07-17 04:28:17	Loading pretrained parameter "encoder.attfp.init_context.attentive_gru.gru.bias_ih".
# 07-17 04:28:17	Loading pretrained parameter "encoder.attfp.init_context.attentive_gru.gru.bias_hh".
# 07-17 04:28:17	Loading pretrained parameter "encoder.attfp.gnn_layers.0.project_edge.1.weight".
# 07-17 04:28:17	Loading pretrained parameter "encoder.attfp.gnn_layers.0.project_edge.1.bias".
# 07-17 04:28:17	Loading pretrained parameter "encoder.attfp.gnn_layers.0.attentive_gru.project_node.1.weight".
# 07-17 04:28:17	Loading pretrained parameter "encoder.attfp.gnn_layers.0.attentive_gru.project_node.1.bias".
# 07-17 04:28:17	Loading pretrained parameter "encoder.attfp.gnn_layers.0.attentive_gru.gru.weight_ih".
# 07-17 04:28:17	Loading pretrained parameter "encoder.attfp.gnn_layers.0.attentive_gru.gru.weight_hh".
# 07-17 04:28:17	Loading pretrained parameter "encoder.attfp.gnn_layers.0.attentive_gru.gru.bias_ih".
# 07-17 04:28:17	Loading pretrained parameter "encoder.attfp.gnn_layers.0.attentive_gru.gru.bias_hh".
# 07-17 04:28:17	Loading pretrained parameter "encoder.attfp.gnn_layers.1.project_edge.1.weight".
# 07-17 04:28:17	Loading pretrained parameter "encoder.attfp.gnn_layers.1.project_edge.1.bias".
# 07-17 04:28:17	Loading pretrained parameter "encoder.attfp.gnn_layers.1.attentive_gru.project_node.1.weight".
# 07-17 04:28:17	Loading pretrained parameter "encoder.attfp.gnn_layers.1.attentive_gru.project_node.1.bias".
# 07-17 04:28:17	Loading pretrained parameter "encoder.attfp.gnn_layers.1.attentive_gru.gru.weight_ih".
# 07-17 04:28:17	Loading pretrained parameter "encoder.attfp.gnn_layers.1.attentive_gru.gru.weight_hh".
# 07-17 04:28:17	Loading pretrained parameter "encoder.attfp.gnn_layers.1.attentive_gru.gru.bias_ih".
# 07-17 04:28:17	Loading pretrained parameter "encoder.attfp.gnn_layers.1.attentive_gru.gru.bias_hh".
# 07-17 04:28:17	Loading pretrained parameter "encoder.readout.readouts.0.compute_logits.0.weight".
# 07-17 04:28:17	Loading pretrained parameter "encoder.readout.readouts.0.compute_logits.0.bias".
# 07-17 04:28:17	Loading pretrained parameter "encoder.readout.readouts.0.project_nodes.1.weight".
# 07-17 04:28:17	Loading pretrained parameter "encoder.readout.readouts.0.project_nodes.1.bias".
# 07-17 04:28:17	Loading pretrained parameter "encoder.readout.readouts.0.gru.weight_ih".
# 07-17 04:28:17	Loading pretrained parameter "encoder.readout.readouts.0.gru.weight_hh".
# 07-17 04:28:17	Loading pretrained parameter "encoder.readout.readouts.0.gru.bias_ih".
# 07-17 04:28:17	Loading pretrained parameter "encoder.readout.readouts.0.gru.bias_hh".
# 07-17 04:28:17	Loading pretrained parameter "encoder.readout.readouts.1.compute_logits.0.weight".
# 07-17 04:28:17	Loading pretrained parameter "encoder.readout.readouts.1.compute_logits.0.bias".
# 07-17 04:28:17	Loading pretrained parameter "encoder.readout.readouts.1.project_nodes.1.weight".
# 07-17 04:28:17	Loading pretrained parameter "encoder.readout.readouts.1.project_nodes.1.bias".
# 07-17 04:28:17	Loading pretrained parameter "encoder.readout.readouts.1.gru.weight_ih".
# 07-17 04:28:17	Loading pretrained parameter "encoder.readout.readouts.1.gru.weight_hh".
# 07-17 04:28:17	Loading pretrained parameter "encoder.readout.readouts.1.gru.bias_ih".
# 07-17 04:28:17	Loading pretrained parameter "encoder.readout.readouts.1.gru.bias_hh".
# 07-17 04:28:17	Loading pretrained parameter "ffn.0.weight".
# 07-17 04:28:17	Loading pretrained parameter "ffn.0.bias".
# 07-17 04:28:17	Loading pretrained parameter "ffn.3.weight".
# 07-17 04:28:17	Loading pretrained parameter "ffn.3.bias".
# 07-17 04:28:17	Loading pretrained parameter "ffn.6.weight".
# 07-17 04:28:17	Loading pretrained parameter "ffn.6.bias".
# 07-17 04:28:17	Loading pretrained parameter "density_estimation.0.mean".
# 07-17 04:28:17	Loading pretrained parameter "density_estimation.0.cov".
# 07-17 04:28:17	Loading pretrained parameter "density_estimation.0.transforms.0.arn.permutation".
# 07-17 04:28:17	Loading pretrained parameter "density_estimation.0.transforms.0.arn.layers.0.weight".
# 07-17 04:28:17	Loading pretrained parameter "density_estimation.0.transforms.0.arn.layers.0.bias".
# 07-17 04:28:17	Loading pretrained parameter "density_estimation.0.transforms.0.arn.layers.0.mask".
# 07-17 04:28:17	Loading pretrained parameter "density_estimation.0.transforms.0.arn.layers.1.weight".
# 07-17 04:28:17	Loading pretrained parameter "density_estimation.0.transforms.0.arn.layers.1.bias".
# 07-17 04:28:17	Loading pretrained parameter "density_estimation.0.transforms.0.arn.layers.1.mask".
# 07-17 04:28:17	Loading pretrained parameter "density_estimation.0.transforms.0.arn.layers.2.weight".
# 07-17 04:28:17	Loading pretrained parameter "density_estimation.0.transforms.0.arn.layers.2.bias".
# 07-17 04:28:17	Loading pretrained parameter "density_estimation.0.transforms.0.arn.layers.2.mask".
# 07-17 04:28:17	Loading pretrained parameter "density_estimation.0.transforms.1.arn.permutation".
# 07-17 04:28:17	Loading pretrained parameter "density_estimation.0.transforms.1.arn.layers.0.weight".
# 07-17 04:28:17	Loading pretrained parameter "density_estimation.0.transforms.1.arn.layers.0.bias".
# 07-17 04:28:17	Loading pretrained parameter "density_estimation.0.transforms.1.arn.layers.0.mask".
# 07-17 04:28:17	Loading pretrained parameter "density_estimation.0.transforms.1.arn.layers.1.weight".
# 07-17 04:28:17	Loading pretrained parameter "density_estimation.0.transforms.1.arn.layers.1.bias".
# 07-17 04:28:17	Loading pretrained parameter "density_estimation.0.transforms.1.arn.layers.1.mask".
# 07-17 04:28:17	Loading pretrained parameter "density_estimation.0.transforms.1.arn.layers.2.weight".
# ...
# 07-17 04:52:59	Best roc-auc Now: 0.929
# 07-17 04:53:00
# 07-17 04:53:00	Start Evaluating on Evaluation Set, EPOCH 150 BATCH 2240
# 100%|██████████| 2/2 [00:00<00:00, 27.55it/s]
# 07-17 04:53:00	roc-auc: 0.892
# 07-17 04:53:00	MCC: 0.593
# 07-17 04:53:00	prc-auc: 0.904
# 07-17 04:53:00	accuracy: 0.790
# 07-17 04:53:00	F1: 0.811
# 07-17 04:53:00	Model not improve for 19 Epochs.
# 07-17 04:53:00	Best roc-auc Now: 0.929
# 07-17 04:53:02
# 07-17 04:53:02	Start Evaluating on Evaluation Set, EPOCH 151 BATCH 2260
# 100%|██████████| 2/2 [00:00<00:00, 29.84it/s]
# 07-17 04:53:02	roc-auc: 0.912
# 07-17 04:53:02	MCC: 0.684
# 07-17 04:53:02	prc-auc: 0.931
# 07-17 04:53:02	accuracy: 0.849
# 07-17 04:53:02	F1: 0.874
# 07-17 04:53:02	Model not improve for 20 Epochs.
# 07-17 04:53:02	Best roc-auc Now: 0.929
# 07-17 04:53:03
# 07-17 04:53:03	Start Evaluating on Evaluation Set, EPOCH 152 BATCH 2280
# 100%|██████████| 2/2 [00:00<00:00, 28.02it/s]
# 07-17 04:53:03	roc-auc: 0.797
# 07-17 04:53:03	MCC: 0.450
# 07-17 04:53:03	prc-auc: 0.851
# 07-17 04:53:03	accuracy: 0.668
# 07-17 04:53:03	F1: 0.642
# 07-17 04:53:03	Model not improve for 21 Epochs.
# 07-17 04:53:03	Best roc-auc Now: 0.929
# 07-17 04:53:05
# 07-17 04:53:05	Start Evaluating on Evaluation Set, EPOCH 154 BATCH 2300
# 100%|██████████| 2/2 [00:00<00:00, 32.36it/s]
# 07-17 04:53:05	roc-auc: 0.895
# 07-17 04:53:05	MCC: 0.633
# 07-17 04:53:05	prc-auc: 0.903
# 07-17 04:53:05	accuracy: 0.815
# 07-17 04:53:05	F1: 0.836
# 07-17 04:53:05	Model not improve for 22 Epochs.
# 07-17 04:53:05	Best roc-auc Now: 0.929
# 07-17 04:53:07
# 07-17 04:53:07	Start Evaluating on Evaluation Set, EPOCH 155 BATCH 2320
# 100%|██████████| 2/2 [00:00<00:00, 27.78it/s]
# 07-17 04:53:07	roc-auc: 0.854
# 07-17 04:53:07	MCC: 0.694
# 07-17 04:53:07	prc-auc: 0.859
# 07-17 04:53:07	accuracy: 0.854
# 07-17 04:53:07	F1: 0.887
# 07-17 04:53:07	Model not improve for 23 Epochs.
# 07-17 04:53:07	Best roc-auc Now: 0.929
# 07-17 04:53:08
# 07-17 04:53:08	Start Evaluating on Evaluation Set, EPOCH 156 BATCH 2340
# 100%|██████████| 2/2 [00:00<00:00, 28.85it/s]
# 07-17 04:53:08	roc-auc: 0.905
# 07-17 04:53:08	MCC: 0.702
# 07-17 04:53:08	prc-auc: 0.927
# 07-17 04:53:08	accuracy: 0.859
# 07-17 04:53:08	F1: 0.885
# 07-17 04:53:08	Model not improve for 24 Epochs.
# 07-17 04:53:08	Best roc-auc Now: 0.929
# 07-17 04:53:10
# 07-17 04:53:10	Start Evaluating on Evaluation Set, EPOCH 158 BATCH 2360
# 100%|██████████| 2/2 [00:00<00:00, 30.08it/s]
# 07-17 04:53:10	roc-auc: 0.916
# 07-17 04:53:10	MCC: 0.672
# 07-17 04:53:10	prc-auc: 0.929
# 07-17 04:53:10	accuracy: 0.844
# 07-17 04:53:10	F1: 0.872
# 07-17 04:53:10	Model not improve for 25 Epochs.
# 07-17 04:53:10	Best roc-auc Now: 0.929
# 07-17 04:53:11
# 07-17 04:53:11	Start Evaluating on Evaluation Set, EPOCH 159 BATCH 2380
# 100%|██████████| 2/2 [00:00<00:00, 30.61it/s]
# 07-17 04:53:11	roc-auc: 0.858
# 07-17 04:53:11	MCC: 0.309
# 07-17 04:53:11	prc-auc: 0.880
# 07-17 04:53:11	accuracy: 0.551
# 07-17 04:53:11	F1: 0.432
# 07-17 04:53:11	Model not improve for 26 Epochs.
# 07-17 04:53:11	Best roc-auc Now: 0.929
# 07-17 04:53:13
# 07-17 04:53:13	Start Evaluating on Evaluation Set, EPOCH 160 BATCH 2400
# 100%|██████████| 2/2 [00:00<00:00, 29.62it/s]
# 07-17 04:53:13	roc-auc: 0.909
# 07-17 04:53:13	MCC: 0.659
# 07-17 04:53:13	prc-auc: 0.927
# 07-17 04:53:13	accuracy: 0.834
# 07-17 04:53:13	F1: 0.860
# 07-17 04:53:13	Model not improve for 27 Epochs.
# 07-17 04:53:13	Best roc-auc Now: 0.929
# 07-17 04:53:14
# 07-17 04:53:14	Start Evaluating on Evaluation Set, EPOCH 162 BATCH 2420
# 100%|██████████| 2/2 [00:00<00:00, 29.11it/s]
# 07-17 04:53:14	roc-auc: 0.886
# 07-17 04:53:14	MCC: 0.656
# 07-17 04:53:14	prc-auc: 0.894
# 07-17 04:53:14	accuracy: 0.834
# 07-17 04:53:14	F1: 0.875
# 07-17 04:53:14	Model not improve for 28 Epochs.
# 07-17 04:53:14	Best roc-auc Now: 0.929
# 07-17 04:53:16
# 07-17 04:53:16	Start Evaluating on Evaluation Set, EPOCH 163 BATCH 2440
# 100%|██████████| 2/2 [00:00<00:00, 29.01it/s]
# 07-17 04:53:16	roc-auc: 0.908
# 07-17 04:53:16	MCC: 0.678
# 07-17 04:53:16	prc-auc: 0.939
# 07-17 04:53:16	accuracy: 0.839
# 07-17 04:53:16	F1: 0.860
# 07-17 04:53:16	Model not improve for 29 Epochs.
# 07-17 04:53:16	Best roc-auc Now: 0.929
# 07-17 04:53:17
# 07-17 04:53:17	Start Evaluating on Evaluation Set, EPOCH 164 BATCH 2460
# 100%|██████████| 2/2 [00:00<00:00, 24.89it/s]
# 07-17 04:53:18	roc-auc: 0.880
# 07-17 04:53:18	MCC: 0.432
# 07-17 04:53:18	prc-auc: 0.881
# 07-17 04:53:18	accuracy: 0.649
# 07-17 04:53:18	F1: 0.609
# 07-17 04:53:18	Model not improve for 30 Epochs.
# 07-17 04:53:18	Best roc-auc Now: 0.929
# 07-17 04:53:18	Finish Training.
# 07-17 04:53:18	Best roc-auc: 0.929
# 07-17 04:53:18	Loading pretrained parameter "encoder.attfp.init_context.project_node.0.weight".
# 07-17 04:53:18	Loading pretrained parameter "encoder.attfp.init_context.project_node.0.bias".
# 07-17 04:53:18	Loading pretrained parameter "encoder.attfp.init_context.project_edge1.0.weight".
# 07-17 04:53:18	Loading pretrained parameter "encoder.attfp.init_context.project_edge1.0.bias".
# 07-17 04:53:18	Loading pretrained parameter "encoder.attfp.init_context.project_edge2.1.weight".
# 07-17 04:53:18	Loading pretrained parameter "encoder.attfp.init_context.project_edge2.1.bias".
# 07-17 04:53:18	Loading pretrained parameter "encoder.attfp.init_context.attentive_gru.edge_transform.1.weight".
# 07-17 04:53:18	Loading pretrained parameter "encoder.attfp.init_context.attentive_gru.edge_transform.1.bias".
# 07-17 04:53:18	Loading pretrained parameter "encoder.attfp.init_context.attentive_gru.gru.weight_ih".
# 07-17 04:53:18	Loading pretrained parameter "encoder.attfp.init_context.attentive_gru.gru.weight_hh".
# 07-17 04:53:18	Loading pretrained parameter "encoder.attfp.init_context.attentive_gru.gru.bias_ih".
# 07-17 04:53:18	Loading pretrained parameter "encoder.attfp.init_context.attentive_gru.gru.bias_hh".
# 07-17 04:53:18	Loading pretrained parameter "encoder.attfp.gnn_layers.0.project_edge.1.weight".
# 07-17 04:53:18	Loading pretrained parameter "encoder.attfp.gnn_layers.0.project_edge.1.bias".
# 07-17 04:53:18	Loading pretrained parameter "encoder.attfp.gnn_layers.0.attentive_gru.project_node.1.weight".
# 07-17 04:53:18	Loading pretrained parameter "encoder.attfp.gnn_layers.0.attentive_gru.project_node.1.bias".
# 07-17 04:53:18	Loading pretrained parameter "encoder.attfp.gnn_layers.0.attentive_gru.gru.weight_ih".
# 07-17 04:53:18	Loading pretrained parameter "encoder.attfp.gnn_layers.0.attentive_gru.gru.weight_hh".
# 07-17 04:53:18	Loading pretrained parameter "encoder.attfp.gnn_layers.0.attentive_gru.gru.bias_ih".
# 07-17 04:53:18	Loading pretrained parameter "encoder.attfp.gnn_layers.0.attentive_gru.gru.bias_hh".
# 07-17 04:53:18	Loading pretrained parameter "encoder.attfp.gnn_layers.1.project_edge.1.weight".
# 07-17 04:53:18	Loading pretrained parameter "encoder.attfp.gnn_layers.1.project_edge.1.bias".
# 07-17 04:53:18	Loading pretrained parameter "encoder.attfp.gnn_layers.1.attentive_gru.project_node.1.weight".
# 07-17 04:53:18	Loading pretrained parameter "encoder.attfp.gnn_layers.1.attentive_gru.project_node.1.bias".
# 07-17 04:53:18	Loading pretrained parameter "encoder.attfp.gnn_layers.1.attentive_gru.gru.weight_ih".
# 07-17 04:53:18	Loading pretrained parameter "encoder.attfp.gnn_layers.1.attentive_gru.gru.weight_hh".
# 07-17 04:53:18	Loading pretrained parameter "encoder.attfp.gnn_layers.1.attentive_gru.gru.bias_ih".
# 07-17 04:53:18	Loading pretrained parameter "encoder.attfp.gnn_layers.1.attentive_gru.gru.bias_hh".
# 07-17 04:53:18	Loading pretrained parameter "encoder.readout.readouts.0.compute_logits.0.weight".
# 07-17 04:53:18	Loading pretrained parameter "encoder.readout.readouts.0.compute_logits.0.bias".
# 07-17 04:53:18	Loading pretrained parameter "encoder.readout.readouts.0.project_nodes.1.weight".
# 07-17 04:53:18	Loading pretrained parameter "encoder.readout.readouts.0.project_nodes.1.bias".
# 07-17 04:53:18	Loading pretrained parameter "encoder.readout.readouts.0.gru.weight_ih".
# 07-17 04:53:18	Loading pretrained parameter "encoder.readout.readouts.0.gru.weight_hh".
# 07-17 04:53:18	Loading pretrained parameter "encoder.readout.readouts.0.gru.bias_ih".
# 07-17 04:53:18	Loading pretrained parameter "encoder.readout.readouts.0.gru.bias_hh".
# 07-17 04:53:18	Loading pretrained parameter "encoder.readout.readouts.1.compute_logits.0.weight".
# 07-17 04:53:18	Loading pretrained parameter "encoder.readout.readouts.1.compute_logits.0.bias".
# 07-17 04:53:18	Loading pretrained parameter "encoder.readout.readouts.1.project_nodes.1.weight".
# 07-17 04:53:18	Loading pretrained parameter "encoder.readout.readouts.1.project_nodes.1.bias".
# 07-17 04:53:18	Loading pretrained parameter "encoder.readout.readouts.1.gru.weight_ih".
# 07-17 04:53:18	Loading pretrained parameter "encoder.readout.readouts.1.gru.weight_hh".
# 07-17 04:53:18	Loading pretrained parameter "encoder.readout.readouts.1.gru.bias_ih".
# 07-17 04:53:18	Loading pretrained parameter "encoder.readout.readouts.1.gru.bias_hh".
# 07-17 04:53:18	Loading pretrained parameter "ffn.0.weight".
# 07-17 04:53:18	Loading pretrained parameter "ffn.0.bias".
# 07-17 04:53:18	Loading pretrained parameter "ffn.3.weight".
# 07-17 04:53:18	Loading pretrained parameter "ffn.3.bias".
# 07-17 04:53:18	Loading pretrained parameter "ffn.6.weight".
# 07-17 04:53:18	Loading pretrained parameter "ffn.6.bias".
# 07-17 04:53:18	Loading pretrained parameter "density_estimation.0.mean".
# 07-17 04:53:18	Loading pretrained parameter "density_estimation.0.cov".
# 07-17 04:53:18	Loading pretrained parameter "density_estimation.0.transforms.0.arn.permutation".
# 07-17 04:53:18	Loading pretrained parameter "density_estimation.0.transforms.0.arn.layers.0.weight".
# 07-17 04:53:18	Loading pretrained parameter "density_estimation.0.transforms.0.arn.layers.0.bias".
# 07-17 04:53:18	Loading pretrained parameter "density_estimation.0.transforms.0.arn.layers.0.mask".
# 07-17 04:53:18	Loading pretrained parameter "density_estimation.0.transforms.0.arn.layers.1.weight".
# 07-17 04:53:18	Loading pretrained parameter "density_estimation.0.transforms.0.arn.layers.1.bias".
# 07-17 04:53:18	Loading pretrained parameter "density_estimation.0.transforms.0.arn.layers.1.mask".
# 07-17 04:53:18	Loading pretrained parameter "density_estimation.0.transforms.0.arn.layers.2.weight".
# 07-17 04:53:18	Loading pretrained parameter "density_estimation.0.transforms.0.arn.layers.2.bias".
# 07-17 04:53:18	Loading pretrained parameter "density_estimation.0.transforms.0.arn.layers.2.mask".
# 07-17 04:53:18	Loading pretrained parameter "density_estimation.0.transforms.1.arn.permutation".
# 07-17 04:53:18	Loading pretrained parameter "density_estimation.0.transforms.1.arn.layers.0.weight".
# 07-17 04:53:18	Loading pretrained parameter "density_estimation.0.transforms.1.arn.layers.0.bias".
# 07-17 04:53:18	Loading pretrained parameter "density_estimation.0.transforms.1.arn.layers.0.mask".
# 07-17 04:53:18	Loading pretrained parameter "density_estimation.0.transforms.1.arn.layers.1.weight".
# 07-17 04:53:18	Loading pretrained parameter "density_estimation.0.transforms.1.arn.layers.1.bias".
# 07-17 04:53:18	Loading pretrained parameter "density_estimation.0.transforms.1.arn.layers.1.mask".
# 07-17 04:53:18	Loading pretrained parameter "density_estimation.0.transforms.1.arn.layers.2.weight".
# 07-17 04:53:18	Loading pretrained parameter "density_estimation.0.transforms.1.arn.layers.2.bias".
# 07-17 04:53:18	Loading pretrained parameter "density_estimation.0.transforms.1.arn.layers.2.mask".
# 07-17 04:53:18	Loading pretrained parameter "density_estimation.1.mean".
# 07-17 04:53:18	Loading pretrained parameter "density_estimation.1.cov".
# 07-17 04:53:18	Loading pretrained parameter "density_estimation.1.transforms.0.arn.permutation".
# 07-17 04:53:18	Loading pretrained parameter "density_estimation.1.transforms.0.arn.layers.0.weight".
# 07-17 04:53:18	Loading pretrained parameter "density_estimation.1.transforms.0.arn.layers.0.bias".
# 07-17 04:53:18	Loading pretrained parameter "density_estimation.1.transforms.0.arn.layers.0.mask".
# 07-17 04:53:18	Loading pretrained parameter "density_estimation.1.transforms.0.arn.layers.1.weight".
# 07-17 04:53:18	Loading pretrained parameter "density_estimation.1.transforms.0.arn.layers.1.bias".
# 07-17 04:53:18	Loading pretrained parameter "density_estimation.1.transforms.0.arn.layers.1.mask".
# 07-17 04:53:18	Loading pretrained parameter "density_estimation.1.transforms.0.arn.layers.2.weight".
# 07-17 04:53:18	Loading pretrained parameter "density_estimation.1.transforms.0.arn.layers.2.bias".
# 07-17 04:53:18	Loading pretrained parameter "density_estimation.1.transforms.0.arn.layers.2.mask".
# 07-17 04:53:18	Loading pretrained parameter "density_estimation.1.transforms.1.arn.permutation".
# 07-17 04:53:18	Loading pretrained parameter "density_estimation.1.transforms.1.arn.layers.0.weight".
# 07-17 04:53:18	Loading pretrained parameter "density_estimation.1.transforms.1.arn.layers.0.bias".
# 07-17 04:53:18	Loading pretrained parameter "density_estimation.1.transforms.1.arn.layers.0.mask".
# 07-17 04:53:18	Loading pretrained parameter "density_estimation.1.transforms.1.arn.layers.1.weight".
# 07-17 04:53:18	Loading pretrained parameter "density_estimation.1.transforms.1.arn.layers.1.bias".
# 07-17 04:53:18	Loading pretrained parameter "density_estimation.1.transforms.1.arn.layers.1.mask".
# 07-17 04:53:18	Loading pretrained parameter "density_estimation.1.transforms.1.arn.layers.2.weight".
# 07-17 04:53:18	Loading pretrained parameter "density_estimation.1.transforms.1.arn.layers.2.bias".
# 07-17 04:53:18	Loading pretrained parameter "density_estimation.1.transforms.1.arn.layers.2.mask".
# 07-17 04:53:18	Loading pretrained parameter "batch_norm.weight".
# 07-17 04:53:18	Loading pretrained parameter "batch_norm.bias".
# 07-17 04:53:18	Loading pretrained parameter "batch_norm.running_mean".
# 07-17 04:53:18	Loading pretrained parameter "batch_norm.running_var".
# 07-17 04:53:18	Loading pretrained parameter "batch_norm.num_batches_tracked".
# 100%|██████████| 2/2 [00:00<00:00, 32.02it/s]
# 100%|██████████| 2/2 [00:00<00:00, 32.13it/s]
# 100%|██████████| 2/2 [00:00<00:00, 34.78it/s]
# 100%|██████████| 2/2 [00:00<00:00, 33.13it/s]
# 07-17 04:53:18	ROUND 0 Valid ROC-AUC 0.9204818515604511 +/- 0.022568190175634863
# 07-17 04:53:18	ROUND 0 Valid PRC-AUC 0.9402587752594016 +/- 0.01510059542993962
# 07-17 04:53:18	ROUND 0 Valid ACC     0.8526355671323704 +/- 0.025178966249791247
# 07-17 04:53:18	ROUND 0 Valid MCC     0.6926891167873549 +/- 0.05303055245183658
# 07-17 04:53:18	ROUND 0 Valid F1      0.882466923127352 +/- 0.021568344905693534
# 07-17 04:53:18	ROUND 0 Valid ECE     0.07294476566372857 +/- 0.012699043360899534
# 07-17 04:53:18	ROUND 0 Valid OFR     0.05815483839716653 +/- 0.018872496050406605
# 07-17 04:53:18	ROUND 0 Valid OFN     0.06007378888783064 +/- 0.03232732975566392
# 07-17 04:53:18	ROUND 0 Valid Brier   0.11084048222365321 +/- 0.01761275096294632
# 07-17 04:53:18
# 07-17 04:53:18	ROUND 0 Test ROC-AUC 0.8231720430107528 +/- 0.020339838619918768
# 07-17 04:53:18	ROUND 0 Test PRC-AUC 0.7287625323451188 +/- 0.041422138241937974
# 07-17 04:53:18	ROUND 0 Test ACC     0.743421052631579 +/- 0.018136906252750294
# 07-17 04:53:18	ROUND 0 Test MCC     0.5051162843374782 +/- 0.030682637958232832
# 07-17 04:53:18	ROUND 0 Test F1      0.7187787103915343 +/- 0.01890916325615776
# 07-17 04:53:18	ROUND 0 Test ECE     0.14362533706194403 +/- 0.0401534300715766
# 07-17 04:53:18	ROUND 0 Test OFR     0.1647502285628562 +/- 0.025251616788043055
# 07-17 04:53:18	ROUND 0 Test OFN     0.06285625902761083 +/- 0.0255544991399411
# 07-17 04:53:18	ROUND 0 Test Brier   0.193242650300943 +/- 0.013561844557228744
# 07-17 04:53:18
# 07-17 04:53:18	ROUND 0 Ensemble Test ROC-AUC 0.857168458781362
# 07-17 04:53:18	ROUND 0 Ensemble Test PRC-AUC 0.7463761820794563
# 07-17 04:53:18	ROUND 0 Ensemble Test ACC 0.7894736842105263
# 07-17 04:53:18	ROUND 0 Ensemble Test MCC 0.599722821945344
# 07-17 04:53:18	ROUND 0 Ensemble Test F1 0.7746478873239436
# 07-17 04:53:18	ROUND 0 Ensemble Test ECE 0.10660883696446516
# 07-17 04:53:18	ROUND 0 Ensemble Test OFR 0.1076923076923077
# 07-17 04:53:18	ROUND 0 Ensemble Test OFN 0.05555555555555555
# 07-17 04:53:18	ROUND 0 Ensemble Test Brier 0.1615247848534476
# 07-17 04:53:18
# -0.9204818515604511
